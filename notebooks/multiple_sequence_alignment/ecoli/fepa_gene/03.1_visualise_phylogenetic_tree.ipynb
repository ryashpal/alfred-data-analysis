# %% [markdown]
# # Visualise phylogenetic tree

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fepa_gene/tree.nwk"
)

p <- ggtree(tree, branch.length = "none")

p
# Out:
# ggtree v3.16.0 Learn more at https://yulab-smu.top/contribution-tree-data/
#
# Please cite:
#
# Shuangbin Xu, Lin Li, Xiao Luo, Meijun Chen, Wenli Tang, Li Zhan, Zehan
# Dai, Tommy T. Lam, Yi Guan, Guangchuang Yu. Ggtree: A serialized data
# object for visualization of a phylogenetic tree and annotation data.
# iMeta 2022, 1(4):e56. doi:10.1002/imt2.56
#
#
# Attaching package: ‘ggtree’
#
#
# The following object is masked from ‘package:ape’:
#
#     rotate
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fepa_gene/tree.nwk"
)

p <- ggtree(tree, layout = "unrooted", branch.length = "none")

p
# Out:
# "daylight" method was used as default layout for unrooted tree.
# Average angle change [1] 0.0166989710931194
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fepa_gene/tree.nwk"
)

p <- ggtree(tree)

p
# Out:
# ! The tree contained negative edge lengths. If you want to ignore the edges,
# you can set `options(ignore.negative.edge=TRUE)`, then re-run ggtree.
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fepa_gene/tree.nwk"
)

p <- ggtree(tree, layout = "daylight")

p
# Out:
# Average angle change [1] 1.14645809666052
#
# Average angle change [2] 1.11309919250252
#
# Average angle change [3] 1.02807816472095
#
# Average angle change [4] 1.04096906389355
#
# Average angle change [5] 1.0131371590304
# plot without title
