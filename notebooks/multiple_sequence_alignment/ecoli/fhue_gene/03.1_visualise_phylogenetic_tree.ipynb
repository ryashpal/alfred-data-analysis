# %% [markdown]
# # Visualise phylogenetic tree

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fhue_gene/tree.nwk"
)

p <- ggtree(tree, branch.length = "none")

p
# Out:
# ggtree v3.16.0 Learn more at https://yulab-smu.top/contribution-tree-data/
#
# Please cite:
#
# Guangchuang Yu. Using ggtree to visualize data on tree-like structures.
# Current Protocols in Bioinformatics. 2020, 69:e96. doi:10.1002/cpbi.96
#
#
# Attaching package: ‘ggtree’
#
#
# The following object is masked from ‘package:ape’:
#
#     rotate
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fhue_gene/tree.nwk"
)

p <- ggtree(tree, layout = "unrooted", branch.length = "none")

p
# Out:
# "daylight" method was used as default layout for unrooted tree.
# Average angle change [1] 0.0194986442789048
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fhue_gene/tree.nwk"
)

p <- ggtree(tree)

p
# Out:
# ! The tree contained negative edge lengths. If you want to ignore the edges,
# you can set `options(ignore.negative.edge=TRUE)`, then re-run ggtree.
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fhue_gene/tree.nwk"
)

p <- ggtree(tree, layout = "daylight")

p
# Out:
# Average angle change [1] 1.22210828707672
#
# Average angle change [2] 0.984295469932472
#
# Average angle change [3] 1.07977111452837
#
# Average angle change [4] 1.07442151758869
#
# Average angle change [5] 1.05633377149556
# plot without title
