# %% [markdown]
# # Visualise phylogenetic tree

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fhub_gene/tree.nwk"
)

p <- ggtree(tree, branch.length = "none")

p
# Out:
# ggtree v3.16.0 Learn more at https://yulab-smu.top/contribution-tree-data/
#
# Please cite:
#
# Guangchuang Yu.  Data Integration, Manipulation and Visualization of
# Phylogenetic Trees (1st edition). Chapman and Hall/CRC. 2022,
# doi:10.1201/9781003279242, ISBN: 9781032233574
#
#
# Attaching package: ‘ggtree’
#
#
# The following object is masked from ‘package:ape’:
#
#     rotate
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fhub_gene/tree.nwk"
)

p <- ggtree(tree, layout = "unrooted", branch.length = "none")

p
# Out:
# "daylight" method was used as default layout for unrooted tree.
# Average angle change [1] 0.0187469661289247
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fhub_gene/tree.nwk"
)

p <- ggtree(tree)

p
# Out:
# ! The tree contained negative edge lengths. If you want to ignore the edges,
# you can set `options(ignore.negative.edge=TRUE)`, then re-run ggtree.
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fhub_gene/tree.nwk"
)

p <- ggtree(tree, layout = "daylight")

p
# Out:
# Average angle change [1] 1.16902274813996
#
# Average angle change [2] 1.14197014643126
#
# Average angle change [3] 1.136860857044
#
# Average angle change [4] 1.13867615847211
#
# Average angle change [5] 1.13426671255538
# plot without title
