# %% [markdown]
# # Visualise phylogenetic tree

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fhuc_gene/tree.nwk"
)

p <- ggtree(tree, branch.length = "none")

p
# Out:
# ggtree v3.16.0 Learn more at https://yulab-smu.top/contribution-tree-data/
#
# Please cite:
#
# Guangchuang Yu, Tommy Tsan-Yuk Lam, Huachen Zhu, Yi Guan. Two methods
# for mapping and visualizing associated data on phylogeny using ggtree.
# Molecular Biology and Evolution. 2018, 35(12):3041-3043.
# doi:10.1093/molbev/msy194
#
#
# Attaching package: ‘ggtree’
#
#
# The following object is masked from ‘package:ape’:
#
#     rotate
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fhuc_gene/tree.nwk"
)

p <- ggtree(tree, layout = "unrooted", branch.length = "none")

p
# Out:
# "daylight" method was used as default layout for unrooted tree.
# Average angle change [1] 0.0131241355683844
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fhuc_gene/tree.nwk"
)

p <- ggtree(tree)

p
# Out:
# ! The tree contained negative edge lengths. If you want to ignore the edges,
# you can set `options(ignore.negative.edge=TRUE)`, then re-run ggtree.
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 15)


library(ape)
library(ggtree)
library(ggplot2)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/fhuc_gene/tree.nwk"
)

p <- ggtree(tree, layout = "daylight")

p
# Out:
# Average angle change [1] 1.23827169973278
#
# Average angle change [2] 1.15817862961558
#
# Average angle change [3] 1.37155611110753
#
# Average angle change [4] 1.35079357629135
#
# Average angle change [5] 1.33075425549314
# plot without title
