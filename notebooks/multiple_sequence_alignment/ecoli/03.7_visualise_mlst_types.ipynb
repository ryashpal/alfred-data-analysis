# %% [markdown]
# # Visualise location information

# %% [markdown]
# ## Visualise

# %%
options(repr.plot.width = 16, repr.plot.height = 12)

library(ape)
library(ggtree)
library(ggplot2)
library(dplyr)
library(readr)
library(tidyr)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/acrF_tree.nwk"
)

mlst_df <- read_csv(
  "~/workspace/genome_data/annotations/e_coli/mlst/mlst_ecoli.csv"
)

df <- data.frame(tube_code = tree$tip.label)

heatmap_data <- df %>%
  left_join(mlst_df, by = "tube_code")

heatmap_data$mlst_type <- factor(heatmap_data$mlst_type)

circ <- ggtree(tree, layout = "circular", branch.length = "none")

rownames(heatmap_data) <- heatmap_data$tube_code

p <- gheatmap(
  circ,
  heatmap_data %>% select(mlst_type),
  offset = .8,
  width = .2,
  colnames = FALSE
)

p
# Out:
# Rows: 595 Columns: 10
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): species, tube_code
# dbl (8): mlst_type, adk, fumC, gyrB, icd, mdh, purA, recA
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# plot without title

# %%
options(repr.plot.width = 16, repr.plot.height = 12)

library(ape)
library(ggtree)
library(ggplot2)
library(dplyr)
library(readr)
library(tidyr)
library(ggnewscale)

tree <- read.tree(
  "~/workspace/genome_data/annotations/e_coli/gene_sequences/acrF_tree.nwk"
)

mlst_df <- read_csv(
  "~/workspace/genome_data/annotations/e_coli/mlst/mlst_ecoli.csv"
)

df <- data.frame(tube_code = tree$tip.label)

heatmap_data <- df %>%
  left_join(mlst_df, by = "tube_code")

heatmap_data$mlst_type <- factor(heatmap_data$mlst_type)

heatmap_data$adk <- factor(heatmap_data$adk)
heatmap_data$fumC <- factor(heatmap_data$fumC)
heatmap_data$gyrB <- factor(heatmap_data$gyrB)
heatmap_data$icd <- factor(heatmap_data$icd)
heatmap_data$mdh <- factor(heatmap_data$mdh)
heatmap_data$purA <- factor(heatmap_data$purA)
heatmap_data$recA <- factor(heatmap_data$recA)

circ <- ggtree(tree, layout = "circular", branch.length = "none")

rownames(heatmap_data) <- heatmap_data$tube_code

p <- gheatmap(
  circ,
  heatmap_data %>% select(mlst_type),
  offset = .8,
  width = .2,
  colnames = FALSE
) +
  new_scale_fill()

p <- gheatmap(
  p,
  heatmap_data %>% select(adk),
  offset = 10,
  width = .2,
  colnames = FALSE
)

p <- gheatmap(
  p,
  heatmap_data %>% select(fumC),
  offset = 20,
  width = .2,
  colnames = FALSE
)

p <- gheatmap(
  p,
  heatmap_data %>% select(gyrB),
  offset = 30,
  width = .2,
  colnames = FALSE
)

p <- gheatmap(
  p,
  heatmap_data %>% select(icd),
  offset = 40,
  width = .2,
  colnames = FALSE
)

p <- gheatmap(
  p,
  heatmap_data %>% select(mdh),
  offset = 50,
  width = .2,
  colnames = FALSE
)

p <- gheatmap(
  p,
  heatmap_data %>% select(purA),
  offset = 60,
  width = .2,
  colnames = FALSE
)

p <- gheatmap(
  p,
  heatmap_data %>% select(recA),
  offset = 70,
  width = .2,
  colnames = FALSE
)

p
# Out:
# Rows: 595 Columns: 10
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): species, tube_code
# dbl (8): mlst_type, adk, fumC, gyrB, icd, mdh, purA, recA
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# Scale for y is already present.
# ...
