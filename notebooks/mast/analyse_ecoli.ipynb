# %% [markdown]
# # Analyse results obtained from MAST webserver for ECOLI cohort

# %% [markdown]
# ## Read data

# %%
import os
from pathlib import Path

import xml.etree.ElementTree as ET

import pandas as pd


data = []

baseDir = Path(os.environ['MEME_SUITE_BASE'], 'data', 'output', '20250211_1500')
for cohortDir in os.listdir(baseDir):
    if cohortDir.endswith('_cohort'):
        cohort = cohortDir.replace('_cohort', '')
        for representationTypeDir in os.listdir(Path(baseDir, cohortDir)):
            representationType = representationTypeDir.replace('_represented', '')
            for tokenDir in os.listdir(Path(baseDir, cohortDir, representationTypeDir)):
                token = tokenDir
                # with open(Path(baseDir, cohortDir, representationTypeDir, tokenDir, ))
                tree = ET.parse(Path(baseDir, cohortDir, representationTypeDir, tokenDir, 'mast.xml'))
                for sequences in tree.getroot()[8]:
                    name = sequences.attrib['name']
                    comment = sequences.attrib['comment']
                    length = sequences.attrib['length']
                    strand = sequences[0].attrib['strand']
                    combined_pvalue = sequences[0].attrib['combined_pvalue']
                    evalue = sequences[0].attrib['evalue']
                    data.append([cohort, representationType, token, name, comment, length, strand, combined_pvalue, evalue])

df = pd.DataFrame(data, columns=['cohort', 'representation_type', 'token', 'name', 'comment', 'length', 'strand', 'combined_pvalue', 'evalue'])
df
# Out:
#          cohort representation_type    token         name  \
# 0    high_score               under  TGGCGCG  b0021|insB1
# 1    high_score               under  TGGCGCG   b0027|lspA
# 2    high_score               under  TGGCGCG   b0087|mraY
# 3    high_score               under  TGGCGCG   b0094|ftsA
# 4    high_score               under  TGGCGCG   b0102|zapD
# ..          ...                 ...      ...          ...
# 280  high_score                over  CGTCTGG   b0927|ycbL
# 281  high_score                over  CGTCTGG   b3732|atpD
# 282  high_score                over  CGTCTGG   b0916|ycaQ
# 283  high_score                over  CGTCTGG   b1650|nemA
# 284  high_score                over  CGTCTGG   b2645|yfjZ
#
#                                                comment length strand  \
# 0    b0021; upstream from 0 to 200; size: 201; feat...    201   both
# 1    b0027; upstream from 0 to 200; size: 201; feat...    201   both
# 2    b0087; upstream from 0 to 200; size: 201; feat...    201   both
# 3    b0094; upstream from 0 to 200; size: 201; feat...    201   both
# 4    b0102; upstream from 0 to 200; size: 201; feat...    201   both
# ..                                                 ...    ...    ...
# 280  b0927; upstream from -26 to 200; size: 227; fe...    227   both
# 281  b3732; upstream from -26 to 200; size: 227; fe...    227   both
# 282  b0916; upstream from -36 to 200; size: 237; fe...    237   both
# 283  b1650; upstream from -36 to 200; size: 237; fe...    237   both
# 284  b2645; upstream from -37 to 200; size: 238; fe...    238   both
#
#     combined_pvalue evalue
# 0          1.62e-02     73
# 1          1.62e-02     73
# 2          1.62e-02     73
# 3          1.62e-02     73
# 4          1.62e-02     73
# ..              ...    ...
# 280        2.11e-02     95
# 281        2.11e-02     95
# 282        2.21e-02     99
# 283        2.21e-02     99
# 284        2.22e-02  1e+02
#
# [285 rows x 9 columns]

# %%
df[df.cohort == 'high_score']
# Out:
#          cohort representation_type    token         name  \
# 0    high_score               under  TGGCGCG  b0021|insB1
# 1    high_score               under  TGGCGCG   b0027|lspA
# 2    high_score               under  TGGCGCG   b0087|mraY
# 3    high_score               under  TGGCGCG   b0094|ftsA
# 4    high_score               under  TGGCGCG   b0102|zapD
# ..          ...                 ...      ...          ...
# 280  high_score                over  CGTCTGG   b0927|ycbL
# 281  high_score                over  CGTCTGG   b3732|atpD
# 282  high_score                over  CGTCTGG   b0916|ycaQ
# 283  high_score                over  CGTCTGG   b1650|nemA
# 284  high_score                over  CGTCTGG   b2645|yfjZ
#
#                                                comment length strand  \
# 0    b0021; upstream from 0 to 200; size: 201; feat...    201   both
# 1    b0027; upstream from 0 to 200; size: 201; feat...    201   both
# 2    b0087; upstream from 0 to 200; size: 201; feat...    201   both
# 3    b0094; upstream from 0 to 200; size: 201; feat...    201   both
# 4    b0102; upstream from 0 to 200; size: 201; feat...    201   both
# ..                                                 ...    ...    ...
# 280  b0927; upstream from -26 to 200; size: 227; fe...    227   both
# 281  b3732; upstream from -26 to 200; size: 227; fe...    227   both
# 282  b0916; upstream from -36 to 200; size: 237; fe...    237   both
# 283  b1650; upstream from -36 to 200; size: 237; fe...    237   both
# 284  b2645; upstream from -37 to 200; size: 238; fe...    238   both
#
#     combined_pvalue evalue
# 0          1.62e-02     73
# 1          1.62e-02     73
# 2          1.62e-02     73
# 3          1.62e-02     73
# 4          1.62e-02     73
# ..              ...    ...
# 280        2.11e-02     95
# 281        2.11e-02     95
# 282        2.21e-02     99
# 283        2.21e-02     99
# 284        2.22e-02  1e+02
#
# [285 rows x 9 columns]

# %%
df[df.cohort == 'low_score']
# Out:
# Empty DataFrame
# Columns: [cohort, representation_type, token, name, comment, length, strand, combined_pvalue, evalue]
# Index: []

# %% [markdown]
# ## Save results

# %%
import os
from pathlib import Path


baseDir = Path(os.environ['MEME_SUITE_BASE'], 'data', 'output', '20250211_1500')

df.to_csv(Path(baseDir, 'summary.csv'), index=False)

# %% [markdown]
# ## Analysis

# %% [markdown]
# ## Number of unique tokens with hits

# %%
df.token.unique()
# Out:
# array(['TGGCGCG', 'CGTCTGG'], dtype=object)

# %%
df[['cohort', 'representation_type', 'token', 'name']].groupby(by=['cohort', 'representation_type', 'token']).count()
# Out:
#                                         name
# cohort     representation_type token
# high_score over                CGTCTGG   112
#            under               TGGCGCG   173

# %% [markdown]
# ## Gene names and counts

# %%
df[df.cohort == 'high_score'].name.value_counts().reset_index().rename(columns={'count': 'gene_count'})['gene_count'].value_counts().reset_index()
# Out:
#    gene_count  count
# 0           1    261
# 1           2     12

# %%
df[df.cohort == 'low_score'].name.value_counts().reset_index().rename(columns={'count': 'gene_count'})['gene_count'].value_counts().reset_index()
# Out:
# Empty DataFrame
# Columns: [gene_count, count]
# Index: []

# %%
df.name.value_counts().reset_index().rename(columns={'count': 'gene_count'})['gene_count'].value_counts().reset_index()
# Out:
#    gene_count  count
# 0           1    261
# 1           2     12

# %%
df[df.cohort == 'high_score'].name.value_counts().reset_index().sort_values(by=['count'], ascending=False)[:12]
# Out:
#           name  count
# 5   b2341|fadJ      2
# 3   b1316|ycjT      2
# 1   b3790|wecD      2
# 0   b3248|yhdE      2
# 4   b1523|yneG      2
# 6   b0183|rnhB      2
# 7   b3952|pflC      2
# 11  b2907|ubiH      2
# 8   b0976|hyaE      2
# 9   b0351|mhpF      2
# 2   b1763|topB      2
# 10  b2767|ygcO      2

# %%
df[df.cohort == 'low_score'].name.value_counts().reset_index().sort_values(by=['count'], ascending=False)
# Out:
# Empty DataFrame
# Columns: [name, count]
# Index: []

# %%
df.name.value_counts().reset_index().sort_values(by=['count'], ascending=False)
# Out:
#           name  count
# 5   b2341|fadJ      2
# 3   b1316|ycjT      2
# 1   b3790|wecD      2
# 0   b3248|yhdE      2
# 4   b1523|yneG      2
# ..         ...    ...
# 94  b2200|ccmB      1
# 93  b2196|ccmF      1
# 92  b2195|dsbE      1
# 91  b2056|wcaD      1
# 99  b2674|nrdI      1
#
# [273 rows x 2 columns]
