# %% [markdown]
# # Overlapping analysis with constant attribution score cutoff (> mean + 5 sd)

# %%
import os
import pandas as pd
from pathlib import Path


bedDir = Path(os.environ['GENOMICS_DATA_BASE'], 'genome_nlp_tokens', 'bed_files', 'ECOLI')

bedDfList = []
for bedFile in os.listdir(bedDir):
    tubeid = bedFile.split('.')[0].split('_')[0]
    tokensDf = pd.read_csv(Path(bedDir, bedFile), sep='\t', names=['contig_id', 'start_position', 'end_position', 'tokens', 'score'])
    tokensDf['tube_id'] = tubeid
    bedDfList.append(tokensDf)

bedDf = pd.concat(bedDfList, ignore_index=True)
bedDf
# Out:
#            contig_id  start_position  end_position      tokens     score  \
# 0                  1               1             3         GAA  0.024555
# 1                  1               4            12   AAACCCCGG  0.019281
# 2                  1              13            17       TCAAT  0.042749
# 3                  1              18            22       AAGGC  0.058446
# 4                  1              23            27       CGGGG -0.002272
# ...              ...             ...           ...         ...       ...
# 247349726          5          259913        259920    GCTACCCG  0.012245
# 247349727          5          259921        259928    TTGGTGTG  0.000125
# 247349728          5          259929        259938  CCTGTTCCGT -0.000540
# 247349729          5          259939        259942        GGCC  0.024973
# 247349730          5          259943        259946        CACC  0.002783
#
#              tube_id
# 0           AH21B049
# 1           AH21B049
# 2           AH21B049
# 3           AH21B049
# 4           AH21B049
# ...              ...
# 247349726  ALF22C077
# 247349727  ALF22C077
# 247349728  ALF22C077
# 247349729  ALF22C077
# 247349730  ALF22C077
#
# [247349731 rows x 6 columns]

# %%
bedDf['token_length'] = bedDf.tokens.apply(lambda x: len(x))
bedDf
# Out:
#            contig_id  start_position  end_position      tokens     score  \
# 0                  1               1             3         GAA  0.024555
# 1                  1               4            12   AAACCCCGG  0.019281
# 2                  1              13            17       TCAAT  0.042749
# 3                  1              18            22       AAGGC  0.058446
# 4                  1              23            27       CGGGG -0.002272
# ...              ...             ...           ...         ...       ...
# 247349726          5          259913        259920    GCTACCCG  0.012245
# 247349727          5          259921        259928    TTGGTGTG  0.000125
# 247349728          5          259929        259938  CCTGTTCCGT -0.000540
# 247349729          5          259939        259942        GGCC  0.024973
# 247349730          5          259943        259946        CACC  0.002783
#
#              tube_id  token_length
# 0           AH21B049             3
# 1           AH21B049             9
# 2           AH21B049             5
# 3           AH21B049             5
# 4           AH21B049             5
# ...              ...           ...
# 247349726  ALF22C077             8
# 247349727  ALF22C077             8
# 247349728  ALF22C077            10
# 247349729  ALF22C077             4
# 247349730  ALF22C077             4
#
# [247349731 rows x 7 columns]

# %%
highscoreCutoff = bedDf.score.mean() + 5 * bedDf.score.std()
highscoreCutoff
# Out:
# np.float64(0.7330234625732099)

# %%
highscoreDf = bedDf[bedDf.score > highscoreCutoff]
highscoreDf
# Out:
#            contig_id  start_position  end_position      tokens     score  \
# 3827800            1          602517        602525   TGACTTTAT  0.919031
# 12539715           2          495006        495011      TTTTAC  0.775967
# 12766605           1          457516        457522     GTCCGGG  0.762983
# 18197339           4          182527        182533     ATCATCA  0.762505
# 21598511           2          582651        582655       TCGAT  0.740959
# 25243767           5          305012        305017      GACATC  0.911065
# 38764601           5          355000        355005      TTGTGT  0.790494
# 47126324           2          417542        417546       CCGAC  0.768237
# 53698868           5          360000        360003        TTAT  0.960895
# 54439550           3          427526        427528         CAT  0.834660
# 56316502           2          355021        355025       GATTG  0.820857
# 57825911           3          367546        367551      GTAAAA  0.755850
# 63086812           5          360012        360018     ATCAGCA  0.838711
# 63511091           2          687507        687509         CAT  0.896534
# 73464257           5          305000        305005      GCGAGT  0.808520
# 79857876           3          305013        305017       AAGGC  0.885659
# 85463637           2          402532        402536       TCGAT  0.946905
# 92334139           5          237542        237550   TGATTTTTG  0.796715
# 92935510           2          312592        312598     GAAGAAG  0.779906
# 100247990          2          572514        572518       GCGAA  0.830413
# 106971408          5          275000        275001          CG  0.994362
# 111175257          5          332501        332506      CAGCCC  0.740807
# 115379780          2          400015        400017         GAG  0.916842
# 117870964          1          622506        622509        GCAG  0.971440
# 119978407          4          305104        305112   AGATATAAA  0.775409
# 120424071          3          305017        305022      GTAAAA  0.826454
# 125986442          5          307522        307524         CAT  0.889829
# 130352087          1          480027        480031       TCGAT  0.870703
# 134170025          1          692514        692523  TCTGGATTTT  0.750821
# 135421606          1          712516        712520       AAGGC  0.761021
# 145060434          5          305166        305174   AGATATAAA  0.795624
# 152360178          5          287510        287516     CCGCGCC  0.866131
# 154348282          5          275000        275004       GCAAT  0.935467
# 164547815          2          365022        365024         CGC  0.814704
# 170101387          4          352505        352507         ACG  0.897411
# 174424920          5          325032        325032           A  0.896811
# 177975756          1          460000        460005      CAGTGG  0.760442
# 183058825          5          225024        225026         TCA  0.743950
# 188271625          5          252518        252520         CAT  0.782255
# 188976892          3          405000        405004       AAGGC  0.789430
# 193126552          1          622503        622507       ATAAG  0.960751
# 195375731          1          480027        480031       TCGAT  0.870703
# 197109127          1         1197500       1197506     CGTTGGC  0.984545
# 197331574          4          382500        382504       GCGGC  0.743090
# 197943648          4          402509        402513       TCGAT  0.991059
# 197998633          5          380015        380020      CGCATC  0.789321
# 200946696          1          597557        597558          GC  0.841844
# 202124369          5          317617        317622      TTATTG  0.777022
# 202230068          2          360000        360004       GTGGG  0.933843
# 216835843          5          357500        357503        TATG  0.825491
# 218504902          4          432514        432516         CGC  0.799942
# 220974321          4          240022        240024         TCA  0.962870
# 230170721          5          360000        360003        TTAT  0.960895
# 232258221          4          322515        322523   ACCAATCAA  0.844752
# 235004184          1          622500        622506     TATCAGC  0.854732
# 235314660          1          602517        602525   TGACTTTAT  0.919031
# 236134152          4          322501        322507     GTAAACC  0.873984
# 243419661          5          305125        305133   AGATATAAA  0.847706
# 245359745          4          260011        260015       ACCGA  0.944409
# 245492092          1          697500        697502         AGG  0.772347
#
#              tube_id  token_length
# 3827800    ALF23B108             9
# 12539715    AH20A001             6
# 12766605    AH20B007             7
# 18197339   ALF23A048             7
# 21598511    AH21C053             5
# 25243767   ALF22F150             6
# 38764601   ALF23A082             6
# 47126324    AH20A024             5
# 53698868    AH20I049             4
# 54439550   ALF22K014             3
# 56316502   ALF23C139             5
# 57825911    AH21C062             6
# 63086812    AH21C050             7
# 63511091    AH21L023             3
# 73464257   ALF22F182             6
# 79857876   ALF22B022             5
# 85463637   ALF22G012             5
# 92334139    AH21F065             9
# 92935510   ALF23A168             7
# 100247990   AH21D011             5
# 106971408   AH18L059             2
# 111175257   AH20B054             6
# 115379780  ALF22E052             3
# 117870964   AH19H076             4
# 119978407   AH19B038             9
# 120424071  ALF22D142             6
# 125986442   AH19G037             3
# 130352087   AH20D013             5
# 134170025   AH20B016            10
# 135421606  ALF23A142             5
# 145060434  ALF23A083             9
# 152360178   AH21H018             7
# 154348282   AH19F021             5
# 164547815  ALF23C184             3
# 170101387   AH18J044             3
# 174424920   AH21E003             1
# 177975756  ALF23C019             6
# 183058825  ALF22F005             3
# 188271625  ALF22G036             3
# 188976892  ALF23C222             5
# 193126552   AH21F031             5
# 195375731   AH20B068             5
# 197109127  ALF22H044             7
# 197331574  ALF22H044             5
# 197943648  ALF22L083             5
# 197998633  ALF22L083             6
# 200946696   AH21F048             2
# 202124369   AH21J004             6
# 202230068   AH19I065             5
# 216835843   AH21J055             4
# 218504902   AH21I022             3
# 220974321  ALF22D139             3
# 230170721   AH19H061             4
# 232258221  ALF22I151             9
# 235004184   AH21D034             7
# 235314660   AH20D044             9
# 236134152  ALF22K174             7
# 243419661   AH19A089             9
# 245359745   AH19D013             5
# 245492092   AH21G042             3

# %%
highscoreDf.token_length.value_counts()
# Out:
# token_length
# 5     16
# 3     11
# 6     10
# 7      8
# 9      7
# 4      4
# 2      2
# 10     1
# 1      1
# Name: count, dtype: int64

# %%
import seaborn as sns

sns.histplot(highscoreDf.token_length, binwidth=1)
# Out:
# <Axes: xlabel='token_length', ylabel='Count'>

# %% [markdown]
# ## Obtain token overlaps with annotations

# %%
import os
import pandas as pd
from pathlib import Path


overlappingFilesDir = Path(os.environ['GENOMICS_DATA_BASE'], 'genome_nlp_tokens', 'overlapping_with_annotations', 'ECOLI')

overlappingDfList = []
for overlappingFile in os.listdir(overlappingFilesDir):
    df = pd.read_csv(Path(overlappingFilesDir, overlappingFile), sep='\t', names=['contig_id', 'start_position', 'end_position', 'tokens', 'score', 'feature_type', 'id', 'name', 'gene', 'atributes'])
    df['tube_code'] = [overlappingFile.split('_')[0]]*df.shape[0]
    overlappingDfList.append(df)
overlappingDf = pd.concat(overlappingDfList, ignore_index=True)
overlappingDf
# Out:
#           contig_id  start_position  end_position        tokens     score  \
# 0                 1             665           671       GAATCAT  0.037687
# 1                 1             672           680     TTTATGAAT  0.023426
# 2                 1             681           683           AAC -0.010186
# 3                 1             684           689        AAAACC  0.024358
# 4                 1             690           698     TTCACCCAG  0.031550
# ...             ...             ...           ...           ...       ...
# 92771815          5          357109        357119   CGGCAGACGAA  0.017858
# 92771816          5          357120        357125        GGGGAT  0.030131
# 92771817          5          357126        357131        GGTGGT  0.045921
# 92771818          5          357132        357138       CAGGTTG -0.022747
# 92771819          5          357139        357150  TGGTGATTGGTC  0.020672
#
#          feature_type            id  \
# 0                 CDS  IGMLFD_00005
# 1                 CDS  IGMLFD_00005
# 2                 CDS  IGMLFD_00005
# 3                 CDS  IGMLFD_00005
# 4                 CDS  IGMLFD_00005
# ...               ...           ...
# 92771815          CDS  KCGHAI_11840
# 92771816          CDS  KCGHAI_11840
# 92771817          CDS  KCGHAI_11840
# 92771818          CDS  KCGHAI_11840
# 92771819          CDS  KCGHAI_11840
#
#                                                       name  gene  \
# 0                         Uncharacterized deacetylase YaiS  yaiS
# 1                         Uncharacterized deacetylase YaiS  yaiS
# 2                         Uncharacterized deacetylase YaiS  yaiS
# 3                         Uncharacterized deacetylase YaiS  yaiS
# 4                         Uncharacterized deacetylase YaiS  yaiS
# ...                                                    ...   ...
# 92771815  Phage-related protein%2C tail assembly protein I   NaN
# 92771816  Phage-related protein%2C tail assembly protein I   NaN
# 92771817  Phage-related protein%2C tail assembly protein I   NaN
# 92771818  Phage-related protein%2C tail assembly protein I   NaN
# 92771819  Phage-related protein%2C tail assembly protein I   NaN
#
#                                                   atributes tube_code
# 0         ID=IGMLFD_00005;Name=Uncharacterized deacetyla...  AH19C036
# 1         ID=IGMLFD_00005;Name=Uncharacterized deacetyla...  AH19C036
# 2         ID=IGMLFD_00005;Name=Uncharacterized deacetyla...  AH19C036
# 3         ID=IGMLFD_00005;Name=Uncharacterized deacetyla...  AH19C036
# 4         ID=IGMLFD_00005;Name=Uncharacterized deacetyla...  AH19C036
# ...                                                     ...       ...
# 92771815  ID=KCGHAI_11840;Name=Phage-related protein%2C ...  AH19F069
# 92771816  ID=KCGHAI_11840;Name=Phage-related protein%2C ...  AH19F069
# 92771817  ID=KCGHAI_11840;Name=Phage-related protein%2C ...  AH19F069
# 92771818  ID=KCGHAI_11840;Name=Phage-related protein%2C ...  AH19F069
# 92771819  ID=KCGHAI_11840;Name=Phage-related protein%2C ...  AH19F069
#
# [92771820 rows x 11 columns]

# %% [markdown]
# ## Obtain annotation overlapping with top tokens

# %%
import pandas as pd

from pathlib import Path


for tokenLengthCutoff in [5, 6, 7, 12, 13, 14]:
    print('tokenLengthCutoff: ', str(tokenLengthCutoff))
    tokensDf = highscoreDf[highscoreDf.token_length == tokenLengthCutoff]
    signatureTokens = tokensDf.tokens.unique()
    tokenOverlapsDfs = []
    for signatureToken in signatureTokens:
        tokenOverlapsDf = overlappingDf[overlappingDf.tokens == signatureToken]
        tokenOverlapsDfs.append(tokenOverlapsDf)
    if tokenOverlapsDfs:
        finalTokenOverlapsDf = pd.concat(tokenOverlapsDfs, ignore_index=True)
        finalTokenOverlapsDf.drop_duplicates().to_csv(Path(os.environ['GENOMICS_DATA_BASE'], 'survival_analysis', 'ECOLI', 'constant_score_overlaping_annotations', 'sd_5_tl_' + str(tokenLengthCutoff) + '.csv'), index=False)
# Out:
# tokenLengthCutoff:  5
# tokenLengthCutoff:  6
# tokenLengthCutoff:  7
# tokenLengthCutoff:  8
# tokenLengthCutoff:  9
# tokenLengthCutoff:  10

# %% [markdown]
# ## Create data for an upset plot

# %%
import os

from pathlib import Path

import pandas as pd


overlappingGenesDict = {}
overlappingAnnotationsDict = {}

for tokenLengthCutoff in [5, 6, 7, 12, 13, 14]:
    print('tokenLengthCutoff: ', str(tokenLengthCutoff))
    overlappingGenesPath = Path(os.environ['GENOMICS_DATA_BASE'], 'survival_analysis', 'ECOLI', 'constant_score_overlaping_annotations', 'sd_5_tl_' + str(tokenLengthCutoff) + '.csv')
    if overlappingGenesPath.exists():
        overlappingGenesDf = pd.read_csv(overlappingGenesPath)
        overlappingGenesDict['Token Length > ' + str(tokenLengthCutoff)] = overlappingGenesDf.gene.unique()
        overlappingAnnotationsDict['Token Length > ' + str(tokenLengthCutoff)] = overlappingGenesDf
# Out:
# tokenLengthCutoff:  5
# tokenLengthCutoff:  6
# tokenLengthCutoff:  7
# tokenLengthCutoff:  12
# tokenLengthCutoff:  13
# tokenLengthCutoff:  14

# %% [markdown]
# ## Generate upset plot

# %%
from upsetplot import UpSet

from upsetplot import from_contents


ax_dict = UpSet(from_contents(overlappingGenesDict), show_counts=True).plot()
# Out:
# /home/vmadmin/workspace/alfred-data-analysis/.venv/lib/python3.10/site-packages/upsetplot/data.py:385: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(False, inplace=True)
# /home/vmadmin/workspace/alfred-data-analysis/.venv/lib/python3.10/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /home/vmadmin/workspace/alfred-data-analysis/.venv/lib/python3.10/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /home/vmadmin/workspace/alfred-data-analysis/.venv/lib/python3.10/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /home/vmadmin/workspace/alfred-data-analysis/.venv/lib/python3.10/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)

# %% [markdown]
# ## Obtain common genes

# %% [markdown]
# ### Overlapping genes in `Token Length > 13`

# %%
overlappingGenesDict['Token Length > 13']
# Out:
# array(['mukB', 'naRNA4', nan], dtype=object)

# %% [markdown]
# ### Combined genes in `Token Length > 12`, `Token Length > 13`

# %%
[set([v for v in value if str(v) != 'nan']) for key, value in overlappingGenesDict.items() if (key in ['Token Length > 12', 'Token Length > 13'])]
# Out:
# [{'aas',
#   'accD',
#   'acrB',
#   'adeP',
#   'adhE',
#   'aer',
#   'agaS',
#   'ahpF',
#   'ahr',
#   'allB',
#   'alsB',
#   'araA',
#   'araB',
#   'araH',
#   'araJ',
#   'argB',
#   'argG',
#   'argH',
#   'arnA',
#   'aroA',
#   'aroD',
#   'arpA',
#   'arsC',
#   'arsR',
#   'ascF',
#   'aslA',
#   'aspS',
#   'baeR',
#   'barA',
#   'bax',
#   'bcr',
#   'betA',
#   'betT',
#   'bglA',
#   'bglX',
#   'bigA',
#   'bioB',
#   'bioF',
#   'caiD',
#   'carB',
#   'cas3',
#   'cbtA',
#   'ccmF',
#   'cdh',
#   'cdiA',
#   'chaC',
#   'citD',
#   'clbN',
#   'clbO',
#   'clpA',
#   'clpP',
#   'cmk',
#   'cniT',
#   'cnoX',
#   'corC',
#   'dacB',
#   'dbpA',
#   'degP',
#   'dgcE',
#   'dgoA',
#   'dhaK',
#   'dhaM',
#   'diaA',
#   'djlC',
#   'dmsC',
#   'dnaB',
#   'dnaK',
#   'dnaX',
#   'dolP',
#   'dppF',
#   'eCs1768',
#   'ecpC',
#   'elfA',
#   'emrA',
#   'emrB',
#   'entE',
#   'epmB',
#   'eptA',
#   'eptB',
#   'ettA',
#   'eutE',
#   'eutT',
#   'fUI1',
#   'fabG',
#   'fadD',
#   'fadE',
#   'fepC',
#   'fhuA',
#   'fhuB',
#   'fieF',
#   'fimA',
#   'fimB',
#   'fimD',
#   'fixA',
#   'fkpB',
#   'flhA',
#   'fliH',
#   'flk',
#   'frwC',
#   'fryC',
#   'ftsE',
#   'ftsK',
#   'fucK',
#   'fumB',
#   'gadB',
#   'galE',
#   'galP',
#   'gcvP',
#   'gfcE',
#   'glaH',
#   'glcB',
#   'glcD',
#   'glcE',
#   'glmS',
#   'glnD',
#   'glnQ',
#   'gltB',
#   'glyS',
#   'gmrSD',
#   'gntP',
#   'gntT',
#   'gpD',
#   'gpr',
#   'grpE',
#   'gspF',
#   'guaA',
#   'guaB',
#   'gudD',
#   'gyrA',
#   'gyrB',
#   'hemA',
#   'hemH',
#   'hflK',
#   'hscA',
#   'hsdM',
#   'hsdR',
#   'hsdS',
#   'htpG',
#   'hutI',
#   'hyaF',
#   'hybE',
#   'hycC',
#   'hycG',
#   'hyfB',
#   'hyfF',
#   'hypD',
#   'hypE',
#   'hypF',
#   'ileS',
#   'infB',
#   'irp1',
#   'irp2',
#   'ispC',
#   'istB',
#   'kdpB',
#   'kdpE',
#   'kefC',
#   'kpsD',
#   'lacZ',
#   'lafU',
#   'ldtD',
#   'lfhA',
#   'lgoT',
#   'lldD',
#   'lolC',
#   'lplT',
#   'ltaE',
#   'lysA',
#   'lysR',
#   'macB',
#   'maeB',
#   'malE',
#   'malS',
#   'manY',
#   'mdtC',
#   'melR',
#   'menB',
#   'menC',
#   'menE',
#   'menF',
#   'mepM',
#   'metB',
#   'metH',
#   'mhpA',
#   'mhpT',
#   'mltD',
#   'mngR',
#   'mnmH',
#   'moaE',
#   'mraY',
#   'mrcA',
#   'mreC',
#   'msbA',
#   'mscK',
#   'mscM',
#   'murD',
#   'murE',
#   'mutL',
#   'mutS',
#   'naRNA4',
#   'nadA',
#   'nagZ',
#   'nanK',
#   'napC',
#   'narG',
#   'narH',
#   'narJ',
#   'narQ',
#   'narU',
#   'narZ',
#   'nepI',
#   'nfrA',
#   'nfsA',
#   'nifJ',
#   'nimR',
#   'norV',
#   'nrdA',
#   'nrfA',
#   'nrfC',
#   'nrfD',
#   'nrfF',
#   'nudG',
#   'nuoH',
#   'nuoL',
#   'nupC',
#   'nupX',
#   'odhB',
#   'ompA',
#   'ompC',
#   'opgE',
#   'ortT',
#   'osmC',
#   'oxc',
#   'paaZ',
#   'paoC',
#   'pat',
#   'patD',
#   'pbpG',
#   'pepP',
#   'pgaB',
#   'pgtB',
#   'pgtP',
#   'pheP',
#   'pheS',
#   'phnM',
#   'pic',
#   'pksD',
#   'pocR',
#   'polB',
#   'pphB',
#   'prmC',
#   'proP',
#   'proX',
#   'prpE',
#   'pspG',
#   'pstC',
#   'pstS',
#   'psuT',
#   'pth',
#   'ptrA',
#   'ptrB',
#   'purL',
#   'putA1',
#   'pxpA',
#   'radD',
#   'rapA',
#   'rayT',
#   'rbsB',
#   'rdgC',
#   'recB',
#   'recC',
#   'recG',
#   'recJ',
#   'rihB',
#   'rluA',
#   'rna',
#   'rne',
#   'rnhB',
#   'rnk',
#   'rpiB',
#   'rpsI',
#   'rsgA',
#   'rssA',
#   'rsxC',
#   'rsxE',
#   'sapC',
#   'sapD',
#   'sapF',
#   'secA',
#   'selB',
#   'selO',
#   'sepA',
#   'serS',
#   'sfaF',
#   'sgrR',
#   'speC',
#   'sslE',
#   'sstT',
#   'ssuB',
#   'ssuD',
#   'stpA',
#   'surA',
#   'syd',
#   'tadD',
#   'tam',
#   'tamB',
#   'tap',
#   'tcdA',
#   'tcfC',
#   'tdcE',
#   'thiI',
#   'tilS',
#   'tmcA',
#   'tnaA',
#   'tnp',
#   'tolA',
#   'torC',
#   'torS',
#   'traC',
#   'traI',
#   'treA',
#   'treB',
#   'treC',
#   'trhO',
#   'trmJ',
#   'trnR',
#   'trpB',
#   'trxB',
#   'trxC',
#   'tsaD',
#   'tssG',
#   'tssJ',
#   'tsuB',
#   'tsx',
#   'ubiF',
#   'ubiH',
#   'uhpC',
#   'uhpT',
#   'ulaA',
#   'ulaD',
#   'ulaG',
#   'umuD',
#   'uup',
#   'uxaB',
#   'uxuR',
#   'vactox',
#   'valS',
#   'vasK',
#   'virB4',
#   'waaA',
#   'wcaC',
#   'wcaK',
#   'wcaL',
#   'wcaM',
#   'wza',
#   'wzx',
#   'wzxC',
#   'xanP',
#   'xdhA',
#   'xdhD',
#   'xerC',
#   'xseB',
#   'xylB',
#   'yaaJ',
#   'yadH',
#   'yadN',
#   'yaeQ',
#   'yafK',
#   'ybbP',
#   'ybbW',
#   'ybcJ',
#   'ybfD',
#   'ybgI',
#   'ybhD',
#   'ybhK',
#   'ybhS',
#   'ybjC',
#   'ybjQ',
#   'ybjT',
#   'ycaC',
#   'ycaD',
#   'yccA',
#   'yccF',
#   'yceM',
#   'yciW',
#   'yciW1',
#   'ycjM',
#   'ydbH',
#   'yddE',
#   'ydgH',
#   'ydhJ',
#   'ydiF',
#   'ydiJ',
#   'yeaG',
#   'yebE',
#   'yecC',
#   'yedD',
#   'yeeA',
#   'yeeU',
#   'yeeX',
#   'yeeY',
#   'yehF',
#   'yehI',
#   'yehM',
#   'yehQ',
#   'yehX',
#   'yejK',
#   'yesN',
#   'yfaS',
#   'yfcC',
#   'yfcH',
#   'ygaV',
#   'ygcR',
#   'ygfI',
#   'yghB',
#   'ygiD',
#   'ygjR',
#   'yhaK',
#   'yhcC',
#   'yheS',
#   'yhfT',
#   'yhhI',
#   'yhjJ',
#   'yidK',
#   'yijO',
#   'yjeJ',
#   'yjiN',
#   'yjjU',
#   'ykgE',
#   'ynjB',
#   'ynjE',
#   'ynjF',
#   'yoaA',
#   'ypdA',
#   'ypdE',
#   'ypfG',
#   'ypfJ',
#   'ypjD',
#   'yqhD',
#   'ytfP',
#   'zapC',
#   'zraS'},
#  {'mukB', 'naRNA4'}]
