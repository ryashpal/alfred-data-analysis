# %% [markdown]
# # Overlapping analysis with constant attribution score cutoff (top 100)

# %%
import pandas as pd


pd.set_option("display.max_columns", None) # show all cols
pd.set_option('display.max_colwidth', None) # show full width of showing cols
pd.set_option("display.expand_frame_repr", False) # print cols side by side as it's supposed to be
pd.set_option('display.max_rows', 500)

# %%
import os
import pandas as pd
from pathlib import Path


bedDir = Path(os.environ['GENOMICS_DATA_BASE'], 'genome_nlp_tokens', 'bed_files', 'SAUR')

bedDfList = []
for bedFile in os.listdir(bedDir):
    tubeid = bedFile.split('.')[0].split('_')[0]
    tokensDf = pd.read_csv(Path(bedDir, bedFile), sep='\t', names=['contig_id', 'start_position', 'end_position', 'tokens', 'score'])
    tokensDf['tube_id'] = tubeid
    bedDfList.append(tokensDf)

bedDf = pd.concat(bedDfList, ignore_index=True)
bedDf
# Out:
#            contig_id  start_position  end_position   tokens     score    tube_id
# 0                  1               0             6  TTTTCTT  0.000064  ALF22G140
# 1                  1               7             9      ACC -0.000395  ALF22G140
# 2                  1              10            13     GACA  0.001573  ALF22G140
# 3                  1              14            18    AGAAT -0.000986  ALF22G140
# 4                  1              19            25  TAATTAT  0.000795  ALF22G140
# ...              ...             ...           ...      ...       ...        ...
# 176721937          5          181665        181667      CGG -0.002273   AH21C044
# 176721938          5          181668        181673   CTCATC -0.001735   AH21C044
# 176721939          5          181674        181676      GCA -0.003468   AH21C044
# 176721940          5          181677        181680     TCCA -0.000228   AH21C044
# 176721941          5          181681        181685    CTTTT -0.003030   AH21C044
#
# [176721942 rows x 6 columns]

# %%
bedDf['token_length'] = bedDf.tokens.apply(lambda x: len(x))
bedDf
# Out:
#            contig_id  start_position  end_position   tokens     score    tube_id  token_length
# 0                  1               0             6  TTTTCTT  0.000064  ALF22G140             7
# 1                  1               7             9      ACC -0.000395  ALF22G140             3
# 2                  1              10            13     GACA  0.001573  ALF22G140             4
# 3                  1              14            18    AGAAT -0.000986  ALF22G140             5
# 4                  1              19            25  TAATTAT  0.000795  ALF22G140             7
# ...              ...             ...           ...      ...       ...        ...           ...
# 176721937          5          181665        181667      CGG -0.002273   AH21C044             3
# 176721938          5          181668        181673   CTCATC -0.001735   AH21C044             6
# 176721939          5          181674        181676      GCA -0.003468   AH21C044             3
# 176721940          5          181677        181680     TCCA -0.000228   AH21C044             4
# 176721941          5          181681        181685    CTTTT -0.003030   AH21C044             5
#
# [176721942 rows x 7 columns]

# %%
highscoreDf = bedDf.sort_values(by=['score'], ascending=False)[:100]
highscoreDf
# Out:
#            contig_id  start_position  end_position    tokens     score    tube_id  token_length
# 12546445           3          300016        300022   TTATATA  0.401408   AH19K071             7
# 30627859           4          292501        292505     TCACA  0.392442   AH20J041             5
# 8636242            4          175077        175082    GAACAT  0.331686  ALF22E035             6
# 8636234            4          175031        175036    TAAACT  0.329530  ALF22E035             6
# 20052075           3          307641        307648  TGATTTTT  0.268324  ALF22F089             8
# ...              ...             ...           ...       ...       ...        ...           ...
# 72019100           3          192912        192918   TAAAACT  0.077782   AH19F010             7
# 8636233            4          175026        175030     TGTAC  0.076539  ALF22E035             5
# 87912711           5          182598        182601      GTGA  0.075881  ALF23C182             4
# 54909373           3          330020        330024     GCGGC  0.075453   AH20C034             5
# 136227253          5          178411        178415     CTTAC  0.075297   AH21H076             5
#
# [100 rows x 7 columns]

# %%
highscoreDf.shape
# Out:
# (100, 7)

# %%
highscoreDf.token_length.value_counts()
# Out:
# token_length
# 5    33
# 6    26
# 4    18
# 7    16
# 3     3
# 8     2
# 9     2
# Name: count, dtype: int64

# %%
import seaborn as sns

sns.histplot(highscoreDf.token_length, binwidth=1)
# Out:
# <Axes: xlabel='token_length', ylabel='Count'>

# %% [markdown]
# ## Obtain token overlaps with annotations

# %%
import os
import pandas as pd
from pathlib import Path


overlappingFilesDir = Path(os.environ['GENOMICS_DATA_BASE'], 'genome_nlp_tokens', 'overlapping_with_annotations', 'SAUR')
overlappingFilesDir.mkdir(parents=True, exist_ok=True)

overlappingDfList = []
for overlappingFile in os.listdir(overlappingFilesDir):
    df = pd.read_csv(Path(overlappingFilesDir, overlappingFile), sep='\t', names=['contig_id', 'start_position', 'end_position', 'tokens', 'score', 'feature_type', 'id', 'name', 'gene', 'atributes'])
    df['tube_code'] = [overlappingFile.split('_')[0]]*df.shape[0]
    overlappingDfList.append(df)
overlappingDf = pd.concat(overlappingDfList, ignore_index=True)
overlappingDf
# Out:
# /tmp/ipykernel_87721/2277659407.py:11: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(Path(overlappingFilesDir, overlappingFile), sep='\t', names=['contig_id', 'start_position', 'end_position', 'tokens', 'score', 'feature_type', 'id', 'name', 'gene', 'atributes'])
# /tmp/ipykernel_87721/2277659407.py:11: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(Path(overlappingFilesDir, overlappingFile), sep='\t', names=['contig_id', 'start_position', 'end_position', 'tokens', 'score', 'feature_type', 'id', 'name', 'gene', 'atributes'])
# /tmp/ipykernel_87721/2277659407.py:11: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(Path(overlappingFilesDir, overlappingFile), sep='\t', names=['contig_id', 'start_position', 'end_position', 'tokens', 'score', 'feature_type', 'id', 'name', 'gene', 'atributes'])
#            contig_id  start_position  end_position    tokens     score feature_type            id                                                                             name  gene                                                                                                                                                                                                                                                                                                                                                                                         atributes tube_code
# 0                  1             127           130      AAAA -0.004951          CDS  OILJNO_00005                                                             acyl carrier protein  acpP                                                                                                                      ID=OILJNO_00005;Name=acyl carrier protein;locus_tag=OILJNO_00005;product=acyl carrier protein;Dbxref=GO:0000036,GO:0005737,GO:0046677,RefSeq:WP_000426914.1,SO:0001217,UniParc:UPI0000125385,UniRef:UniRef100_A7X1J8,UniRef:UniRef50_A7X1J8,UniRef:UniRef90_A7X1J8;gene=acpP  AH20I016
# 1                  1             131           134      TTTC -0.000510          CDS  OILJNO_00005                                                             acyl carrier protein  acpP                                                                                                                      ID=OILJNO_00005;Name=acyl carrier protein;locus_tag=OILJNO_00005;product=acyl carrier protein;Dbxref=GO:0000036,GO:0005737,GO:0046677,RefSeq:WP_000426914.1,SO:0001217,UniParc:UPI0000125385,UniRef:UniRef100_A7X1J8,UniRef:UniRef50_A7X1J8,UniRef:UniRef90_A7X1J8;gene=acpP  AH20I016
# 2                  1             135           137       GAT -0.009607          CDS  OILJNO_00005                                                             acyl carrier protein  acpP                                                                                                                      ID=OILJNO_00005;Name=acyl carrier protein;locus_tag=OILJNO_00005;product=acyl carrier protein;Dbxref=GO:0000036,GO:0005737,GO:0046677,RefSeq:WP_000426914.1,SO:0001217,UniParc:UPI0000125385,UniRef:UniRef100_A7X1J8,UniRef:UniRef50_A7X1J8,UniRef:UniRef90_A7X1J8;gene=acpP  AH20I016
# 3                  1             138           145  AAAGTAAA  0.009005          CDS  OILJNO_00005                                                             acyl carrier protein  acpP                                                                                                                      ID=OILJNO_00005;Name=acyl carrier protein;locus_tag=OILJNO_00005;product=acyl carrier protein;Dbxref=GO:0000036,GO:0005737,GO:0046677,RefSeq:WP_000426914.1,SO:0001217,UniParc:UPI0000125385,UniRef:UniRef100_A7X1J8,UniRef:UniRef50_A7X1J8,UniRef:UniRef90_A7X1J8;gene=acpP  AH20I016
# 4                  1             146           151    AGATAT -0.010377          CDS  OILJNO_00005                                                             acyl carrier protein  acpP                                                                                                                      ID=OILJNO_00005;Name=acyl carrier protein;locus_tag=OILJNO_00005;product=acyl carrier protein;Dbxref=GO:0000036,GO:0005737,GO:0046677,RefSeq:WP_000426914.1,SO:0001217,UniParc:UPI0000125385,UniRef:UniRef100_A7X1J8,UniRef:UniRef50_A7X1J8,UniRef:UniRef90_A7X1J8;gene=acpP  AH20I016
# ...              ...             ...           ...       ...       ...          ...           ...                                                                              ...   ...                                                                                                                                                                                                                                                                                                                                                                                               ...       ...
# 136910729          5          205776        205781    ATTTTT -0.002056          CDS  KKIOAG_10525  Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase  pulO  ID=KKIOAG_10525;Name=Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase;locus_tag=KKIOAG_10525;product=Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase;Dbxref=COG:COG1989,COG:NU,RefSeq:WP_000261111.1,SO:0001217,UniParc:UPI0001DDA595,UniRef:UniRef100_A0A0D1JKS9,UniRef:UniRef50_A0A0D1JKS9,UniRef:UniRef90_A0A0D1JKS9;gene=pulO  AH21K020
# 136910730          5          205782        205787    AGGAGG  0.000008          CDS  KKIOAG_10525  Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase  pulO  ID=KKIOAG_10525;Name=Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase;locus_tag=KKIOAG_10525;product=Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase;Dbxref=COG:COG1989,COG:NU,RefSeq:WP_000261111.1,SO:0001217,UniParc:UPI0001DDA595,UniRef:UniRef100_A0A0D1JKS9,UniRef:UniRef50_A0A0D1JKS9,UniRef:UniRef90_A0A0D1JKS9;gene=pulO  AH21K020
# 136910731          5          205788        205790       CGT -0.002779          CDS  KKIOAG_10525  Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase  pulO  ID=KKIOAG_10525;Name=Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase;locus_tag=KKIOAG_10525;product=Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase;Dbxref=COG:COG1989,COG:NU,RefSeq:WP_000261111.1,SO:0001217,UniParc:UPI0001DDA595,UniRef:UniRef100_A0A0D1JKS9,UniRef:UniRef50_A0A0D1JKS9,UniRef:UniRef90_A0A0D1JKS9;gene=pulO  AH21K020
# 136910732          5          205791        205798  ATATTTTT -0.000752          CDS  KKIOAG_10525  Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase  pulO  ID=KKIOAG_10525;Name=Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase;locus_tag=KKIOAG_10525;product=Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase;Dbxref=COG:COG1989,COG:NU,RefSeq:WP_000261111.1,SO:0001217,UniParc:UPI0001DDA595,UniRef:UniRef100_A0A0D1JKS9,UniRef:UniRef50_A0A0D1JKS9,UniRef:UniRef90_A0A0D1JKS9;gene=pulO  AH21K020
# 136910733          5          205799        205799         G  0.000828          CDS  KKIOAG_10525  Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase  pulO  ID=KKIOAG_10525;Name=Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase;locus_tag=KKIOAG_10525;product=Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase;Dbxref=COG:COG1989,COG:NU,RefSeq:WP_000261111.1,SO:0001217,UniParc:UPI0001DDA595,UniRef:UniRef100_A0A0D1JKS9,UniRef:UniRef50_A0A0D1JKS9,UniRef:UniRef90_A0A0D1JKS9;gene=pulO  AH21K020
#
# [136910734 rows x 11 columns]

# %% [markdown]
# ## Obtain annotation overlapping with top tokens

# %%
import pandas as pd

from pathlib import Path


for tokenLengthCutoff in range(5, 11):
    print('tokenLengthCutoff: ', str(tokenLengthCutoff))
    tokensDf = highscoreDf[highscoreDf.token_length == tokenLengthCutoff]
    signatureTokens = tokensDf.tokens.unique()
    tokenOverlapsDfs = []
    for signatureToken in signatureTokens:
        tokenOverlapsDf = overlappingDf[overlappingDf.tokens == signatureToken]
        tokenOverlapsDfs.append(tokenOverlapsDf)
    if tokenOverlapsDfs:
        top100OverlapsPath = Path(os.environ['GENOMICS_DATA_BASE'], 'survival_analysis', 'SAUR', 'constant_score_overlaping_annotations')
        top100OverlapsPath.mkdir(parents=True, exist_ok=True)
        finalTokenOverlapsDf = pd.concat(tokenOverlapsDfs, ignore_index=True)
        finalTokenOverlapsDf.drop_duplicates().to_csv(Path(top100OverlapsPath, 'top_100_tl_' + str(tokenLengthCutoff) + '.csv'), index=False)
# Out:
# tokenLengthCutoff:  5
# tokenLengthCutoff:  6
# tokenLengthCutoff:  7
# tokenLengthCutoff:  8
# tokenLengthCutoff:  9
# tokenLengthCutoff:  10

# %% [markdown]
# ## Create data for an upset plot

# %%
import os

from pathlib import Path

import pandas as pd


overlappingGenesDict = {}
overlappingAnnotationsDict = {}

for tokenLengthCutoff in range(5, 11):
    print('tokenLengthCutoff: ', str(tokenLengthCutoff))
    overlappingGenesPath = Path(os.environ['GENOMICS_DATA_BASE'], 'survival_analysis', 'SAUR', 'constant_score_overlaping_annotations', 'top_100_tl_' + str(tokenLengthCutoff) + '.csv')
    if overlappingGenesPath.exists():
        overlappingGenesDf = pd.read_csv(overlappingGenesPath)
        overlappingGenesDict['Token Length > ' + str(tokenLengthCutoff)] = overlappingGenesDf.gene.unique()
        overlappingAnnotationsDict['Token Length > ' + str(tokenLengthCutoff)] = overlappingGenesDf
# Out:
# tokenLengthCutoff:  5
# tokenLengthCutoff:  6
# tokenLengthCutoff:  7
# tokenLengthCutoff:  8
# tokenLengthCutoff:  9
# tokenLengthCutoff:  10

# %% [markdown]
# ## Generate upset plot

# %%
from upsetplot import UpSet

from upsetplot import from_contents


ax_dict = UpSet(from_contents(overlappingGenesDict), show_counts=True, sort_categories_by='input').plot()
# Out:
# /home/vmadmin/workspace/alfred-data-analysis/.venv/lib/python3.10/site-packages/upsetplot/data.py:385: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(False, inplace=True)
# /home/vmadmin/workspace/alfred-data-analysis/.venv/lib/python3.10/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /home/vmadmin/workspace/alfred-data-analysis/.venv/lib/python3.10/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /home/vmadmin/workspace/alfred-data-analysis/.venv/lib/python3.10/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /home/vmadmin/workspace/alfred-data-analysis/.venv/lib/python3.10/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)

# %% [markdown]
# ## Obtain singature genes

# %%
singatureGenes = set()

# %% [markdown]
# ### Common overlapping genes

# %%
singatureGenes.update(set.intersection(*[set([v for v in value if str(v) != 'nan']) for key, value in overlappingGenesDict.items()]))

# %% [markdown]
# ### Common genes in `Token Length > 5`, `Token Length > 6`, `Token Length > 8`, `Token Length > 9`, `Token Length > 10`

# %%
# singatureGenes.update(set.intersection(*[set([v for v in value if str(v) != 'nan']) for key, value in overlappingGenesDict.items() if (key and (key != 'Token Length > 7'))]))

# %% [markdown]
# ### Common genes in `Token Length > 5`, `Token Length > 6`, `Token Length > 7`, `Token Length > 9`, `Token Length > 10`

# %%
# singatureGenes.update(set.intersection(*[set([v for v in value if str(v) != 'nan']) for key, value in overlappingGenesDict.items() if (key and (key != 'Token Length > 8'))]))

# %% [markdown]
# ### Common genes in `Token Length > 5`, `Token Length > 6`, `Token Length > 7`, `Token Length > 8`, `Token Length > 10`

# %%
# singatureGenes.update(set.intersection(*[set([v for v in value if str(v) != 'nan']) for key, value in overlappingGenesDict.items() if (key and (key != 'Token Length > 9'))]))

# %% [markdown]
# ### Common genes in `Token Length > 5`, `Token Length > 6`, `Token Length > 7`, `Token Length > 8`, `Token Length > 9`

# %%
# singatureGenes.update(set.intersection(*[set([v for v in value if str(v) != 'nan']) for key, value in overlappingGenesDict.items() if (key and (key != 'Token Length > 10'))]))

# %% [markdown]
# ## Display signature gene names

# %%
singatureGenes
# Out:
# {'aceF',
#  'addA',
#  'addB',
#  'aes',
#  'ansP',
#  'araJ',
#  'argF',
#  'arsB',
#  'aur',
#  'azoR',
#  'betB',
#  'bglG',
#  'bshA',
#  'capN',
#  'ccmA',
#  'ccmC',
#  'citM',
#  'coa',
#  'coiA',
#  'comEC',
#  'dinG',
#  'dnaG',
#  'dppD',
#  'eap',
#  'ebh',
#  'era',
#  'esaA',
#  'fadM',
#  'fbp',
#  'femA',
#  'fmhA',
#  'fnbA',
#  'fnbB',
#  'frwC',
#  'ftsI',
#  'ftsK',
#  'glpG',
#  'gntR',
#  'hdeD',
#  'hemA',
#  'hlgC',
#  'holA',
#  'hsdS',
#  'hslU',
#  'isaA',
#  'isdD',
#  'lacG',
#  'lolC',
#  'ltaA',
#  'ltrA',
#  'lukD',
#  'lukS-PV',
#  'lysR',
#  'mazF',
#  'menC',
#  'mngR',
#  'mnhE2',
#  'oafA',
#  'opuBB',
#  'orf47',
#  'pbuX',
#  'pitA',
#  'pnp',
#  'priA',
#  'proP',
#  'pstS',
#  'purF',
#  'purL',
#  'recJ',
#  'rfaB',
#  'ribE',
#  'rnj1',
#  'rpiR',
#  'sasF',
#  'sau3AIR',
#  'sbcC',
#  'sdrC',
#  'sdrG',
#  'sfaD',
#  'smc',
#  'splB',
#  'spn',
#  'srmB',
#  'tarL',
#  'tdcB',
#  'tehA',
#  'tnp',
#  'topA',
#  'traG',
#  'trkA',
#  'ushA',
#  'uvrA',
#  'uvrC',
#  'vraG',
#  'vwb',
#  'xerD',
#  'ydcZ',
#  'yedE',
#  'yfcH',
#  'yfhO',
#  'yhgE',
#  'yhiN',
#  'ymcA'}

# %% [markdown]
# ## Display signature genes along with their description

# %%
overlappingDf[['name', 'gene']][overlappingDf.gene.isin(singatureGenes)].drop_duplicates().sort_values(by=['gene'])
# Out:
#                                                                                                                                                                 name     gene
# 53574                                                               Pyruvate/2-oxoglutarate dehydrogenase complex%2C dihydrolipoamide acyltransferase (E2) component     aceF
# 186223                                                                                                                       helicase-exonuclease AddAB subunit AddA     addA
# 185595                                                                                                                       helicase-exonuclease AddAB subunit AddB     addB
# 166763                                                                                                                                        Acetyl esterase/lipase      aes
# 80971                                                                                                                   L-asparagine transporter or related permease     ansP
# 293162                                                                                                         putative arabinose efflux permease AraJ%2C MFS family     araJ
# 150278                                                                                                                                ornithine carbamoyltransferase     argF
# 1104506                                                                                                            arsenite efflux transporter membrane subunit ArsB     arsB
# 149697                                                                                                                             zinc metalloproteinase aureolysin      aur
# 105676                                                                                                                     FMN-dependent NADH:quinone oxidoreductase     azoR
# 154691                                                                                                                                betaine-aldehyde dehydrogenase     betB
# 35754863                                                                                                                    BglG family transcription antiterminator     bglG
# 98621                                                                                                                                 Transcriptional antiterminator     bglG
# 11424929                                                                             Activator of the mannose operon (Transcriptional antiterminator)%2C BglG family     bglG
# 44909                                                                                                           N-acetyl-alpha-D-glucosaminyl L-malate synthase BshA     bshA
# 114963                                                                                                  capsular polysaccharide type 5/8 biosynthesis epimerase CapN     capN
# 5043509                                                                                                                Heme ABC transporter ATP-binding protein CcmA     ccmA
# 15949                                                                                                        ABC-type multidrug transport system%2C ATPase component     ccmA
# 205263                                                                                                                    heme ABC exporter ATP-binding protein CcmA     ccmA
# 76265                                                                            ABC-type transport system involved in cytochrome c biogenesis%2C permease component     ccmC
# 153476                                                                                                                                        Mg2+/citrate symporter     citM
# 101885                                                                                                                                             staphylocoagulase      coa
# 28218873                                                                                                                                     Competence protein CoiA     coiA
# 192242                                                                                                  Competence protein CoiA%2C contains putative nuclease domain     coiA
# 64443                                                                                                      DNA internalization-related competence protein ComEC/Rec2    comEC
# 18626815                                                                    DNA uptake channel protein ComEC C-terminal domain%2C metallo-beta-lactamase superfamily    comEC
# 44031                                                                                                                                         3'-5' exonuclease DinG     dinG
# 60282                                                                                                                                                    DNA primase     dnaG
# 190217                                                                                   ABC-type dipeptide/oligopeptide/nickel transport system%2C ATPase component     dppD
# 1169550                                                                                                                      extracellular adherence protein Eap/Map      eap
# 34811                                                                                                                       Extracellular matrix-binding protein ebh      ebh
# 4007111                                                                                                                       hyperosmolarity resistance protein Ebh      ebh
# 61242                                                                                                                                                     GTPase Era      era
# 41535                                                                                                                  GTPase Era%2C involved in 16S rRNA processing      era
# 2116980                                                                                                              Type VII secretion system accessory factor EsaA     esaA
# 4072170                                                                                                                              type VII secretion protein EsaA     esaA
# 91305                                                                                                                         type VII secretion system protein EsaA     esaA
# 21226                                                                                                                                     Acyl-CoA thioesterase FadM     fadM
# 169412                                                                                                                         Fructose-1%2C6-bisphosphatase class 3      fbp
# 1614324                                                                                                                                    Aminoacyltransferase FemA     femA
# 25441                                                                                                                                 glycine glycyltransferase FemA     femA
# 315161                                                                                                                       FemA/FemB family glycyltransferase FmhA     fmhA
# 32044062                                                                                                                                                FmhA protein     fmhA
# 6614287                                                                                                                                fibronectin-binding protein A     fnbA
# 806135                                                                                                                                 Fibronectin-binding protein A     fnbA
# 1351038                                                                                                                             fibronectin-binding protein FnbA     fnbA
# 856700                                                                                                                              Fibronectin-binding protein FnbA     fnbA
# 6614835                                                                                                                                fibronectin-binding protein B     fnbB
# 856194                                                                                                                              Fibronectin-binding protein FnbB     fnbB
# 172649                                                                                                                              fibronectin-binding protein FnbB     fnbB
# 167158                                                                                                  Phosphotransferase system%2C fructose-specific IIC component     frwC
# 29802105  Cell division protein FtsI [Peptidoglycan synthetase] / Transpeptidase%2C Penicillin binding protein transpeptidase domain%2C Penicillin-binding protein 3     ftsI
# 58519                                                                      Cell division protein FtsI%2C peptidoglycan transpeptidase (Penicillin-binding protein 2)     ftsI
# 8845                                                                                                                                            DNA translocase FtsK     ftsK
# 436103                                                                                                        DNA segregation ATPase FtsK/SpoIIIE or related protein     ftsK
# 9620312                                                                                                                                   Cell division protein FtsK     ftsK
# 58130                                                                                                         Membrane-associated serine protease%2C rhomboid family     glpG
# 2625620                                                                                                                        GntR family transcriptional regulator     gntR
# 171408                                                                                                          DNA-binding transcriptional regulator%2C GntR family     gntR
# 137810                                                                                                                              DUF308 domain-containing protein     hdeD
# 10911306                                                                                                      Putative pyridoxal phosphate-dependent acyltransferase     hemA
# 76408                                                                                                                                        glutamyl-tRNA reductase     hemA
# 6135344                                                                                                                                  Gamma-hemolysin component C     hlgC
# 316765                                                                                                                  bi-component gamma-hemolysin HlgCB subunit C     hlgC
# 64279                                                                                                                               DNA polymerase III subunit delta     holA
# 5141345                                                                                                                        putative specificity determinant HsdS     hsdS
# 25986496                                                                                                                                                        HsdS     hsdS
# 6939095                                                                                                           EcoKI restriction-modification system protein HsdS     hsdS
# 4976482                                                                                                                           Restriction endonuclease S subunit     hsdS
# 65413118                                                                                                             ATP-dependent protease ATP-binding subunit HslU     hslU
# 4348                                                                                                                      ATP-dependent protease ATPase subunit HslU     hslU
# 1499076                                                                                                                               putative transglycosylase IsaA     isaA
# 160490                                                                                                                                   lytic transglycosylase IsaA     isaA
# 213750                                                                                                                  iron-regulated surface determinant protein D     isdD
# 523148                                                                                                               iron-regulated surface determinant protein IsdD     isdD
# 284510                                                                                                                                  6-phospho-beta-galactosidase     lacG
# 345411                                                                          ABC-type transport system involved in lipoprotein release%2C permease component LolC     lolC
# 195285                                                                                                                       Proton-coupled antiporter flippase LtaA     ltaA
# 1742912                                                                                                               group II intron reverse transcriptase/maturase     ltrA
# 338020                                                                                                   Low temperature requirement protein LtrA (function unknown)     ltrA
# 4697036                                                                                                                      bi-component leukocidin LukED subunit D     lukD
# 2031625                                                                                                                                              Leucotoxin LukD     lukD
# 4181099                                                                                                           Panton-Valentine bi-component leukocidin subunit S  lukS-PV
# 3726352                                                                                                                               LysR family regulatory protein     lysR
# 99322868                                                                                                                       LysR family transcriptional regulator     lysR
# 165552                                                                                                          DNA-binding transcriptional regulator%2C LysR family     lysR
# 99320378                                                                                                            LysR substrate-binding domain-containing protein     lysR
# 231250                                                                                                                                         Endoribonuclease MazF     mazF
# 1106719                                                                                                                                  o-succinylbenzoate synthase     menC
# 9269                                                                                                            DNA-binding transcriptional regulator%2C GntR family     mngR
# 261729                                                                                                                              Na+/H+ antiporter Mnh2 subunit E    mnhE2
# 187758                                                                                                                           Putative O-acetyltransferase MW0856     oafA
# 321614                                                                                       ABC-type proline/glycine betaine transport system%2C permease component    opuBB
# 14437536                                                                                                                                  phage major capsid protein    orf47
# 333208                                                                                                                                      Xanthine/uracil permease     pbuX
# 255867                                                                                                                                    Phosphate/sulfate permease     pitA
# 8147                                                                                                                       polyribonucleotide nucleotidyltransferase      pnp
# 226046                                                                                                                                         primosomal protein N'     priA
# 269040                                                                                                                          Putative proline/betaine transporter     proP
# 321357                                                                                              MFS family permease%2C includes anhydromuropeptide permease AmpG     proP
# 61748460                                                                                     phosphate ABC transporter substrate-binding protein PstS family protein     pstS
# 1727403                                                                                                 ABC-type phosphate transport system%2C periplasmic component     pstS
# 27840                                                                                                                                 Phosphate-binding protein PstS     pstS
# 204058                                                                                                                                amidophosphoribosyltransferase     purF
# 203661                                                                                                       phosphoribosylformylglycinamidine synthase subunit PurL     purL
# 71811                                                                                                                  single-stranded-DNA-specific exonuclease RecJ     recJ
# 121114                                                                                                         Glycosyltransferase involved in cell wall bisynthesis     rfaB
# 1103850                                                                                                                                          riboflavin synthase     ribE
# 1103548                                                                                                                    6%2C7-dimethyl-8-ribityllumazine synthase     ribE
# 207224                                                                                                                                              Ribonuclease J 1     rnj1
# 108464                                                                     DNA-binding transcriptional regulator%2C MurR/RpiR family%2C contains HTH and SIS domains     rpiR
# 147296                                                                                                                               cell-wall-anchored protein SasF     sasF
# 398468                                                                                                                                             Surface protein F     sasF
# 673727                                                                                                                Sau3AI family type II restriction endonuclease  sau3AIR
# 19805                                                                                                                                       Nuclease SbcCD subunit C     sbcC
# 72379590                                                                                                                                            Exonuclease SbcC     sbcC
# 1415965                                                                                                                                  MSCRAMM family adhesin SdrC     sdrC
# 37731847                                                                                              Ser-Asp rich fibrinogen/bone sialoprotein-binding protein SdrC     sdrC
# 272022                                                                                             Ser-Asp rich fibrinogen-binding bone sialoprotein-binding protein     sdrC
# 38807758                                                                                                                             Fibrinogen-binding protein SdrC     sdrC
# 877480                                                                                          fibrinogen-binding adhesin SdrG C-terminal domain-containing protein     sdrG
# 283107                                                                                                                              D-ornithine--citrate ligase SfaD     sfaD
# 174                                                                                                                               chromosome segregation protein SMC      smc
# 38003941                                                                                                                                        Serine protease SplB     splB
# 4696419                                                                                                                                         serine protease SplB     splB
# 79756501                                                                                                                            SPIN family peroxidase inhibitor      spn
# 329272                                                                                                                                myeloperoxidase inhibitor SPIN      spn
# 327855                                                                                                                               ATP-dependent RNA helicase SrmB     srmB
# 96358                                                                                                                Teichoic acid ribitol-phosphate polymerase TarL     tarL
# 40995                                                                                               bifunctional threonine ammonia-lyase/L-serine ammonia-lyase TdcB     tdcB
# 219271                                                                                                       Tellurite resistance protein TehA and related permeases     tehA
# 3791893                                                                                                                                IS6 family ISSau6 transposase      tnp
# 710933                                                                                                                         IS200/IS605 family ISSep3 transposase      tnp
# 26125202                                                                                                                                      IS6 family transposase      tnp
# 329725                                                                                                                                ISL3 family IS1181 transposase      tnp
# 11413001                                                                                                                               IS30 family transposase ORF B      tnp
# 67312184                                                                                                                         IS3 family ISSau4 transposase ORF A      tnp
# 1729421                                                                                                                         IS30 family ISSau5 transposase ORF B      tnp
# 1729529                                                                                                                         IS30 family ISSau5 transposase ORF A      tnp
# 78660894                                                                                                                              ISL3 family ISSau8 transposase      tnp
# 1736583                                                                                                                                 IS3 family transposase ORF B      tnp
# 1736726                                                                                                                          IS3 family ISSau2 transposase ORF A      tnp
# 4383061                                                                                                                              IS6 family IS431mec transposase      tnp
# 4381975                                                                                                                                    IS1182 family transposase      tnp
# 1831368                                                                                                                               IS200/IS605 family transposase      tnp
# 91227930                                                                                                                                    IS256 family transposase      tnp
# 28888791                                                                                                                            IS1182 family ISSau3 transposase      tnp
# 3464                                                                                                                                        type I DNA topoisomerase     topA
# 2630631                                                                                                                               Conjugal transfer protein TraG     traG
# 193822                                                                                 Trk/Ktr K+ transport system regulatory component TrkA/KtrA/KtrC%2C RCK domain     trkA
# 118339                                                               2'%2C3'-cyclic-nucleotide 2'-phosphodiesterase/5'- or 3'-nucleotidase%2C 5'-nucleotidase family     ushA
# 240199                                                                                                                                 excinuclease ABC subunit UvrA     uvrA
# 216316                                                                                                                                 excinuclease ABC subunit UvrC     uvrC
# 256163                                                                                                                                 ABC transporter permease VraG     vraG
# 235099                                                                                                                     von Willebrand factor binding protein Vwb      vwb
# 2267702                                                                                                     secreted von Willebrand factor-binding protein precursor      vwb
# 50850                                                                                                                        site-specific tyrosine recombinase XerD     xerD
# 262639                                                                                                                                Site-specific recombinase XerD     xerD
# 262816                                                                                                                              DUF606 domain-containing protein     ydcZ
# 2636762                                                                          Uncharacterized membrane protein YedE/YeeE%2C contains two sulfur transport domains     yedE
# 238504                                                                                                                               Epimerase family protein MW0731     yfcH
# 26258785                                                                                                                                         YfhO family protein     yfhO
# 1759                                                                                                             lipoteichoic acid-specific glycosyltransferase YfhO     yfhO
# 148087                                                                                 Uncharacterized membrane protein YhgE%2C phage infection protein (PIP) family     yhgE
# 1100555                                                                                                                                   putative flavoprotein YhiN     yhiN
# 11972                                                                                                                               DUF963 domain-containing protein     ymcA

# %% [markdown]
# ## Export tokens to visualise

# %%
highscoreOverlappingFilesDir = Path(os.environ['GENOMICS_DATA_BASE'], 'genome_nlp_tokens', 'highscore_overlapping', 'SAUR')
highscoreOverlappingFilesDir.mkdir(parents=True, exist_ok=True)

for tubeCode in overlappingDf.tube_code.unique():
    print('tubeCode: ', tubeCode)
    highscoreOverlappingDf = overlappingDf[(overlappingDf.tube_code == tubeCode)].merge(
        highscoreDf[['tokens']],
        how='inner',
        on=['tokens']
    )[['contig_id', 'start_position', 'end_position', 'tokens']].drop_duplicates()
    highscoreOverlappingFile = Path(highscoreOverlappingFilesDir, tubeCode + '.bed')
    highscoreOverlappingDf.to_csv(highscoreOverlappingFile, sep='\t', index=False, header=None)
# Out:
# tubeCode:  AH20I016
# tubeCode:  ALF22H103
# tubeCode:  AH19C024
# tubeCode:  AH20K011
# tubeCode:  AH21G019
# tubeCode:  ALF22F117
# tubeCode:  ALF22D054
# tubeCode:  AH19E051
# tubeCode:  ALF22C052
# tubeCode:  AH19E065
# tubeCode:  AH21C012
# tubeCode:  ALF22I003
# tubeCode:  AH19L024
# tubeCode:  AH19L067
# tubeCode:  AH21B039
# tubeCode:  AH19G028
# tubeCode:  AH20A069
# tubeCode:  AH18K050
# tubeCode:  ALF22L122
# tubeCode:  AH20K007
# tubeCode:  AH21K075
# tubeCode:  ALF22E103
# tubeCode:  AH21G070
# tubeCode:  AH20A072
# tubeCode:  AH19A010
# tubeCode:  AH19H009
# tubeCode:  AH20K032
# tubeCode:  AH21K071
# tubeCode:  AH21A090
# tubeCode:  AH21A083
# tubeCode:  AH21J061
# tubeCode:  AH20I032
# tubeCode:  AH22A022
# tubeCode:  AH18J073
# tubeCode:  AH19B059
# tubeCode:  AH21I089
# tubeCode:  AH19C070
# tubeCode:  AH18K039
# tubeCode:  AH20I045
# tubeCode:  ALF22G032
# tubeCode:  AH20F012
# tubeCode:  AH18J022
# tubeCode:  AH19A063
# tubeCode:  AH20L041
# tubeCode:  AH21J006
# tubeCode:  AH19A088
# tubeCode:  AH18J002
# tubeCode:  ALF22L144
# tubeCode:  ALF22L118
# tubeCode:  AH20B030
# tubeCode:  AH19G060
# tubeCode:  ALF22L140
# tubeCode:  ALF22L040
# tubeCode:  AH19D043
# tubeCode:  AH18K074
# tubeCode:  AH20L075
# tubeCode:  AH20E041
# tubeCode:  AH19G024
# tubeCode:  AH19F074
# tubeCode:  AH21A010
# tubeCode:  AH21C022
# tubeCode:  AH20C042
# tubeCode:  AH19A043
# tubeCode:  ALF22J082
# tubeCode:  AH19E017
# tubeCode:  AH19C101
# tubeCode:  AH21H054
# tubeCode:  ALF22C122
# tubeCode:  AH20H034
# tubeCode:  AH21J013
# tubeCode:  ALF22L020
# tubeCode:  AH21G026
# tubeCode:  AH19H053
# tubeCode:  ALF23A040
# tubeCode:  AH22A055
# tubeCode:  ALF22E051
# tubeCode:  AH18J063
# tubeCode:  AH20I050
# tubeCode:  AH19I070
# tubeCode:  AH20C041
# tubeCode:  AH19F010
# tubeCode:  AH19H034
# tubeCode:  AH20G020
# tubeCode:  AH20L010
# tubeCode:  AH19H046
# tubeCode:  AH19J035
# tubeCode:  AH21I033
# tubeCode:  AH19A008
# tubeCode:  ALF22K018
# tubeCode:  ALF23A041
# tubeCode:  ALF22E049
# tubeCode:  AH18K028
# tubeCode:  ALF22E105
# tubeCode:  AH19K084
# tubeCode:  AH20G066
# tubeCode:  AH20H007
# tubeCode:  AH19F045
# tubeCode:  ALF22H073
# tubeCode:  AH19B026
# tubeCode:  AH20H053
# tubeCode:  AH19J013
# tubeCode:  ALF22F167
# tubeCode:  AH21B038
# tubeCode:  ALF22E079
# tubeCode:  AH20E051
# tubeCode:  AH20K064
# tubeCode:  AH20I013
# tubeCode:  ALF22D135
# tubeCode:  ALF22D020
# tubeCode:  AH21F012
# tubeCode:  AH18J037
# tubeCode:  AH19K014
# tubeCode:  AH20A046
# tubeCode:  AH20A038
# tubeCode:  AH21K089
# tubeCode:  AH19D022
# tubeCode:  AH20I029
# tubeCode:  AH21K065
# tubeCode:  AH20C026
# tubeCode:  ALF22C039
# tubeCode:  AH20J014
# tubeCode:  AH21E001
# tubeCode:  ALF22D138
# tubeCode:  ALF22L085
# tubeCode:  AH19D037
# tubeCode:  AH18K071
# tubeCode:  ALF22I073
# tubeCode:  AH19B051
# tubeCode:  AH21I023
# tubeCode:  AH18L029
# tubeCode:  AH21C041
# tubeCode:  AH18J021
# tubeCode:  AH21L072
# tubeCode:  AH21I013
# tubeCode:  AH19A042
# tubeCode:  AH19I050
# tubeCode:  AH20H038
# tubeCode:  AH19D079
# tubeCode:  AH21G032
# tubeCode:  ALF22F125
# tubeCode:  AH22A149
# tubeCode:  AH19D017
# tubeCode:  AH21J047
# tubeCode:  AH20A031
# tubeCode:  AH20E040
# tubeCode:  AH20A054
# tubeCode:  AH19F013
# tubeCode:  ALF22I075
# tubeCode:  AH21K008
# tubeCode:  AH20A048
# tubeCode:  ALF22G016
# tubeCode:  AH19A032
# tubeCode:  AH18L025
# tubeCode:  AH22A001
# tubeCode:  ALF22C126
# tubeCode:  AH18K073
# tubeCode:  AH20J031
# tubeCode:  AH20I039
# tubeCode:  AH21E079
# tubeCode:  AH18L078
# tubeCode:  AH20H013
# tubeCode:  AH20L076
# tubeCode:  AH21K024
# tubeCode:  AH20F004
# tubeCode:  ALF22D128
# tubeCode:  AH20F047
# tubeCode:  AH20B052
# tubeCode:  AH20K061
# tubeCode:  ALF22C152
# tubeCode:  AH19A012
# tubeCode:  AH18K024
# tubeCode:  ALF22K037
# tubeCode:  ALF22F050
# tubeCode:  ALF23A010
# tubeCode:  AH18K040
# tubeCode:  AH21H015
# tubeCode:  AH20I027
# tubeCode:  AH19A038
# tubeCode:  AH18L026
# tubeCode:  ALF22I148
# tubeCode:  AH20L045
# tubeCode:  AH20B021
# tubeCode:  AH21B002
# tubeCode:  AH21E027
# tubeCode:  AH20F041
# tubeCode:  AH21H028
# tubeCode:  AH20L035
# tubeCode:  AH20E048
# tubeCode:  AH21A081
# tubeCode:  AH18J014
# tubeCode:  AH20F085
# tubeCode:  AH19K005
# tubeCode:  AH20H027
# tubeCode:  AH20H004
# tubeCode:  AH21H055
# tubeCode:  ALF22E082
# tubeCode:  AH19B049
# tubeCode:  AH20L030
# tubeCode:  AH20I021
# tubeCode:  AH20G075
# tubeCode:  AH19E027
# tubeCode:  AH20B028
# tubeCode:  ALF22E116
# tubeCode:  AH19D030
# tubeCode:  AH19K013
# tubeCode:  AH20F023
# tubeCode:  ALF22G114
# tubeCode:  AH21G002
# tubeCode:  ALF22G105
# tubeCode:  AH18J081
# tubeCode:  AH19A007
# tubeCode:  AH21A048
# tubeCode:  AH18J065
# tubeCode:  AH21E032
# tubeCode:  ALF22L079
# tubeCode:  AH19E059
# tubeCode:  AH19B086
# tubeCode:  AH21E065
# tubeCode:  ALF22D091
# tubeCode:  AH21J034
# tubeCode:  ALF22C050
# tubeCode:  AH18L058
# tubeCode:  AH21C002
# tubeCode:  AH21F010
# tubeCode:  AH22A020
# tubeCode:  ALF22D159
# tubeCode:  ALF22L019
# tubeCode:  AH19K019
# tubeCode:  AH18K057
# tubeCode:  ALF22I129
# tubeCode:  ALF22J049
# tubeCode:  ALF22J066
# tubeCode:  AH20L029
# tubeCode:  ALF22D044
# tubeCode:  AH21E069
# tubeCode:  AH21G074
# tubeCode:  AH19D004
# tubeCode:  ALF22B135
# tubeCode:  ALF22D157
# tubeCode:  ALF22K142
# tubeCode:  AH21H029
# tubeCode:  AH18L076
# tubeCode:  AH20C077
# tubeCode:  AH18J075
# tubeCode:  ALF22C008
# tubeCode:  ALF23A081
# tubeCode:  ALF22J133
# tubeCode:  AH18J045
# tubeCode:  AH21A034
# tubeCode:  AH19B060
# tubeCode:  ALF22C078
# tubeCode:  AH21K025
# tubeCode:  AH22A089
# tubeCode:  ALF22F089
# tubeCode:  AH22A112
# tubeCode:  AH19J044
# tubeCode:  AH19L011
# tubeCode:  AH20F070
# tubeCode:  AH21A043
# tubeCode:  AH21C047
# tubeCode:  AH22A009
# tubeCode:  AH20H052
# tubeCode:  AH20D055
# tubeCode:  AH20J034
# tubeCode:  AH19E069
# tubeCode:  AH19J022
# tubeCode:  AH21K007
# tubeCode:  ALF22F023
# tubeCode:  AH19I035
# tubeCode:  AH19A091
# tubeCode:  ALF23A071
# tubeCode:  AH19I061
# tubeCode:  AH21A011
# tubeCode:  AH19A072
# tubeCode:  AH20L079
# tubeCode:  AH20C060
# tubeCode:  AH19F054
# tubeCode:  AH21F038
# tubeCode:  AH20L093
# tubeCode:  AH20E013
# tubeCode:  AH18K008
# tubeCode:  ALF22I145
# tubeCode:  AH18J001
# tubeCode:  ALF22D045
# tubeCode:  AH19K021
# tubeCode:  ALF22I034
# tubeCode:  AH21L019
# tubeCode:  AH19K065
# tubeCode:  AH21H047
# tubeCode:  AH19I022
# tubeCode:  ALF22G118
# tubeCode:  AH22A086
# tubeCode:  AH21J064
# tubeCode:  AH18K047
# tubeCode:  AH20K029
# tubeCode:  AH19A015
# tubeCode:  ALF22D158
# tubeCode:  AH20I042
# tubeCode:  AH18K010
# tubeCode:  AH19F068
# tubeCode:  ALF22D085
# tubeCode:  AH21J052
# tubeCode:  AH21L045
# tubeCode:  AH20J039
# tubeCode:  AH20L044
# tubeCode:  AH19K081
# tubeCode:  AH21A045
# tubeCode:  AH19G021
# tubeCode:  AH20G044
# tubeCode:  AH19F031
# tubeCode:  AH19E037
# tubeCode:  AH21D030
# tubeCode:  ALF22L078
# tubeCode:  AH20K063
# tubeCode:  AH20E058
# tubeCode:  AH21E085
# tubeCode:  AH18J051
# tubeCode:  AH20B075
# tubeCode:  ALF22E015
# tubeCode:  AH18J036
# tubeCode:  ALF22B096
# tubeCode:  AH20F067
# tubeCode:  AH20A021
# tubeCode:  ALF22G140
# tubeCode:  AH19H051
# tubeCode:  AH19C020
# tubeCode:  AH21A072
# tubeCode:  AH19L066
# tubeCode:  AH21D047
# tubeCode:  AH19C025
# tubeCode:  AH18J053
# tubeCode:  AH21F063
# tubeCode:  AH20K016
# tubeCode:  AH20G032
# tubeCode:  AH21D074
# tubeCode:  AH19I072
# tubeCode:  AH20C072
# tubeCode:  ALF22L159
# tubeCode:  AH21L115
# tubeCode:  AH22A007
# tubeCode:  AH19J064
# tubeCode:  AH19D067
# tubeCode:  ALF22J100
# tubeCode:  AH20A025
# tubeCode:  AH20B051
# tubeCode:  AH19B044
# tubeCode:  AH19C041
# tubeCode:  AH21I080
# tubeCode:  AH20A041
# tubeCode:  ALF22K152
# tubeCode:  AH20C034
# tubeCode:  AH20D059
# tubeCode:  AH21H076
# tubeCode:  AH22A002
# tubeCode:  AH18L080
# tubeCode:  AH21D015
# tubeCode:  AH19B053
# tubeCode:  AH21L073
# tubeCode:  ALF22C109
# tubeCode:  ALF22K039
# tubeCode:  AH22A118
# tubeCode:  AH21J017
# tubeCode:  AH18K044
# tubeCode:  ALF22B047
# tubeCode:  ALF22I124
# tubeCode:  AH20C048
# tubeCode:  ALF22E143
# tubeCode:  AH19L027
# tubeCode:  ALF23A039
# tubeCode:  AH19F053
# tubeCode:  AH19C097
# tubeCode:  AH21C073
# tubeCode:  AH19J028
# tubeCode:  ALF22L022
# tubeCode:  AH19F072
# tubeCode:  ALF22F172
# tubeCode:  AH19H044
# tubeCode:  ALF22E113
# tubeCode:  AH18K016
# tubeCode:  AH19L044
# tubeCode:  AH18L005
# tubeCode:  AH19A048
# tubeCode:  AH21E039
# tubeCode:  AH21D039
# tubeCode:  AH21I087
# tubeCode:  AH19J034
# tubeCode:  AH19K018
# tubeCode:  AH19J036
# tubeCode:  AH19F033
# tubeCode:  AH20G045
# tubeCode:  ALF22K009
# tubeCode:  AH21E078
# tubeCode:  AH19H024
# tubeCode:  ALF22E107
# tubeCode:  AH20B069
# tubeCode:  AH20L063
# tubeCode:  AH21B064
# tubeCode:  AH21A053
# tubeCode:  AH21D049
# tubeCode:  ALF22C043
# tubeCode:  ALF22B045
# tubeCode:  AH18K062
# tubeCode:  ALF22J055
# tubeCode:  AH20L024
# tubeCode:  ALF22D060
# tubeCode:  AH19L062
# tubeCode:  AH21H060
# tubeCode:  AH19E054
# tubeCode:  AH18J030
# tubeCode:  AH21C004
# tubeCode:  AH21H068
# tubeCode:  ALF22H060
# tubeCode:  AH21L048
# tubeCode:  AH19C087
# tubeCode:  AH20L008
# tubeCode:  AH20K055
# tubeCode:  AH21B028
# tubeCode:  AH20F086
# tubeCode:  ALF22F033
# tubeCode:  AH19I043
# tubeCode:  AH21J074
# tubeCode:  AH20C031
# tubeCode:  AH20J052
# tubeCode:  ALF22E035
# tubeCode:  AH19A053
# tubeCode:  AH19F042
# tubeCode:  AH18K023
# tubeCode:  AH21C075
# tubeCode:  AH21J041
# tubeCode:  ALF23A036
# tubeCode:  AH18J055
# tubeCode:  AH19C012
# tubeCode:  AH19C019
# tubeCode:  AH20J041
# tubeCode:  AH19H057
# tubeCode:  AH19F055
# tubeCode:  AH19E041
# tubeCode:  ALF22L121
# tubeCode:  AH20I011
# tubeCode:  AH21I027
# tubeCode:  AH19B005
# tubeCode:  ALF22C040
# tubeCode:  AH21L013
# tubeCode:  AH19C034
# tubeCode:  AH19G031
# tubeCode:  AH19A098
# tubeCode:  ALF22D086
# tubeCode:  AH22A123
# tubeCode:  ALF22I018
# tubeCode:  AH18K002
# tubeCode:  AH19B014
# tubeCode:  ALF22G069
# tubeCode:  AH19D042
# tubeCode:  AH20I003
# tubeCode:  AH20A064
# tubeCode:  AH19C075
# tubeCode:  AH21A075
# tubeCode:  AH20J071
# tubeCode:  AH21C014
# tubeCode:  AH19B074
# tubeCode:  AH21H043
# tubeCode:  AH20J033
# tubeCode:  ALF22D145
# tubeCode:  AH19D055
# tubeCode:  AH20F033
# tubeCode:  AH19B029
# tubeCode:  AH19H023
# tubeCode:  ALF22J023
# tubeCode:  AH19D034
# tubeCode:  AH20I057
# tubeCode:  ALF23A038
# tubeCode:  ALF22L141
# tubeCode:  AH19L060
# tubeCode:  ALF23A051
# tubeCode:  ALF22E059
# tubeCode:  ALF22L046
# tubeCode:  ALF22L090
# tubeCode:  AH19I034
# tubeCode:  ALF22I005
# tubeCode:  ALF22I087
# tubeCode:  ALF22L151
# tubeCode:  AH20K040
# tubeCode:  AH21F068
# tubeCode:  AH19K027
# tubeCode:  AH19I040
# tubeCode:  AH20B084
# tubeCode:  ALF22G079
# tubeCode:  AH19L045
# tubeCode:  AH21K063
# tubeCode:  AH18L024
# tubeCode:  AH21C044
# tubeCode:  ALF22K137
# tubeCode:  AH21L068
# tubeCode:  AH18L036
# tubeCode:  AH19H078
# tubeCode:  AH20L088
# tubeCode:  AH21F009
# tubeCode:  AH20C005
# tubeCode:  AH21J015
# tubeCode:  AH19C091
# tubeCode:  ALF22K094
# tubeCode:  AH19J068
# tubeCode:  AH21E083
# tubeCode:  AH21L032
# tubeCode:  AH21L011
# tubeCode:  AH21A007
# tubeCode:  AH20G069
# tubeCode:  AH19K071
# tubeCode:  ALF22G116
# tubeCode:  AH21I005
# tubeCode:  AH20A004
# tubeCode:  AH21K072
# tubeCode:  AH20G036
# tubeCode:  AH21K067
# tubeCode:  AH21K020
