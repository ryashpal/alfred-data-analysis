# %% [markdown]
# # Plot country of birth visual for the patient cohort

# %% [markdown]
# ## Read demographics data

# %%
import os

from pathlib import Path

import pandas as pd


demoDf = pd.read_csv(Path(os.environ['EHR_DATA_BASE'], 'blood_pos_cohort_20240119', '2024-01-17-blood-demo-data.csv'))
demoDf
# Out:
#         PATIENT_ID  EPISODE_ID  PARENT_EPISODE_ID STATUS STATUS_DESCRIPTION  \
# 0          2115118         208                208      D         Discharged
# 1          2153458         384                384      D         Discharged
# 2          2084952         581                581      D         Discharged
# 3          2127622         741                741      D         Discharged
# 4          2115118         749                749      D         Discharged
# ...            ...         ...                ...    ...                ...
# 634303     2144087    17706631           17706631      D         Discharged
# 634304     2176650    17706804           17706430      D         Discharged
# 634305     2141254    17707082           17707082      D         Discharged
# 634306     2080379    17707256           17707256      D         Discharged
# 634307     2141254    17707713           17707082      D         Discharged
#
#                  START_DATETIME             END_DATETIME  \
# 0       2013-07-22 12:28:00.000  2013-07-22 18:00:00.000
# 1       2013-07-23 07:30:00.000  2013-07-23 13:15:00.000
# 2       2013-07-24 03:09:00.000  2013-07-27 14:56:00.000
# 3       2013-07-24 11:59:00.000  2013-07-24 18:30:00.000
# 4       2013-07-24 12:38:00.000  2013-07-24 18:18:00.000
# ...                         ...                      ...
# 634303  2023-05-12 19:18:00.000  2023-05-12 23:59:59.000
# 634304  2023-05-12 20:59:00.000  2023-05-13 00:03:00.000
# 634305  2023-05-13 08:41:46.000  2023-05-13 20:00:00.000
# 634306  2023-05-18 13:30:00.000  2023-05-18 16:10:00.000
# 634307  2023-05-13 20:00:00.000  2023-05-21 15:46:00.000
#
#            DATEOFDEATH_DATETIME   DATE_OF_BIRTH_DATETIME  \
# 0                           NaN  1950-02-25 00:00:00.000
# 1       2019-09-03 22:04:00.000  1938-12-22 00:00:00.000
# 2                           NaN  1992-09-04 00:00:00.000
# 3       2020-05-12 00:00:00.000  1938-09-11 00:00:00.000
# 4                           NaN  1950-02-25 00:00:00.000
# ...                         ...                      ...
# 634303                      NaN  1981-07-13 00:00:00.000
# 634304                      NaN  1959-11-29 00:00:00.000
# 634305                      NaN  1940-01-18 00:00:00.000
# 634306                      NaN  1986-02-10 00:00:00.000
# 634307                      NaN  1940-01-18 00:00:00.000
#
#                 COUNTRY_OF_BIRTH     SEX  READMISSION_FLAG
# 0                      Australia    Male               0.0
# 1                      Mauritius  Female               0.0
# 2                      Australia    Male               0.0
# 3                      Australia    Male               0.0
# 4                      Australia    Male               0.0
# ...                          ...     ...               ...
# 634303  United States of America  Female               NaN
# 634304                 Australia    Male               0.0
# 634305                 Australia    Male               NaN
# 634306                 Australia  Female               0.0
# 634307                 Australia    Male               0.0
#
# [634308 rows x 12 columns]

# %%
demoDf[['PATIENT_ID', 'EPISODE_ID']].drop_duplicates().shape
# Out:
# (634308, 2)

# %% [markdown]
# ## Read data matrix

# %%
import os

from pathlib import Path

import pandas as pd


dmDf = pd.read_csv(Path(os.environ['EHR_DATA_BASE'], 'blood_pos_cohort_20240614', 'data', 'wb_365_wa_3', 'data_matrix_mortality.csv'))
dmDf
# Out:
#        person_id  visit_occurrence_id measurement_date admittime_adm  \
# 0        2133327               567916       2018-09-05    2018-11-26
# 1        2197822               572108       2018-07-25    2019-04-16
# 2        2138701               584423       2018-10-29    2018-11-12
# 3         330958               584875       2018-10-22    2019-03-02
# 4         330958               584875       2018-10-29    2019-03-02
# ...          ...                  ...              ...           ...
# 34983    2514680             17883870       2023-07-06    2023-07-03
# 34984    2449953             17907968       2023-07-11    2023-07-11
# 34985    2449953             17907968       2023-07-12    2023-07-11
# 34986    2449953             17907968       2023-07-13    2023-07-11
# 34987    2449953             17907968       2023-07-14    2023-07-11
#
#       dischtime_adm  vitals_Peripheral oxygen saturation_avg  \
# 0        05/09/2018                               100.000000
# 1        25/07/2018                                96.000000
# 2        02/10/2018                                97.683062
# 3        13/03/2019                                97.666667
# 4        13/03/2019                                96.666667
# ...             ...                                      ...
# 34983    04/07/2023                                94.629630
# 34984    11/07/2023                                97.800000
# 34985    11/07/2023                                98.000000
# 34986    11/07/2023                                97.500000
# 34987    11/07/2023                                98.333333
#
#        vitals_Respiratory rate_avg  vitals_Temperature_avg  \
# 0                        16.000000               36.200000
# 1                        18.398811               36.600000
# 2                        12.000000               36.736949
# 3                        18.000000               36.133333
# 4                        17.333333               36.500000
# ...                            ...                     ...
# 34983                    15.461538               36.006250
# 34984                    17.200000               36.755556
# 34985                    18.166667               37.050000
# 34986                    17.800000               36.840000
# 34987                    17.500000               36.566667
#
#        vitals_Systolic blood pressure_avg  \
# 0                              116.000000
# 1                              120.000000
# 2                              110.000000
# 3                              111.000000
# 4                              119.000000
# ...                                   ...
# 34983                          112.411192
# 34984                          107.916667
# 34985                          115.666667
# 34986                          124.800000
# 34987                          113.500000
#
#        vitals_Diastolic blood pressure_avg  ...  \
# 0                                62.000000  ...
# 1                                63.000000  ...
# 2                                60.004900  ...
# 3                                65.666667  ...
# 4                                72.333333  ...
# ...                                    ...  ...
# 34983                            57.790538  ...
# 34984                            59.166667  ...
# 34985                            60.833333  ...
# 34986                            81.400000  ...
# 34987                            61.500000  ...
#
#        labs_Total alkaline phosphatase level_last  \
# 0                                          223.33
# 1                                          536.00
# 2                                          225.64
# 3                                          133.81
# 4                                          142.64
# ...                                           ...
# 34983                                       88.00
# 34984                                      167.00
# 34985                                      155.00
# 34986                                      158.00
# 34987                                      208.00
#
#        labs_Total protein measurement_last  labs_Globulin_last  \
# 0                                    65.56               39.00
# 1                                    55.00               36.00
# 2                                    68.63               38.93
# 3                                    78.96               42.00
# 4                                    77.10               42.00
# ...                                    ...                 ...
# 34983                                53.00               17.00
# 34984                                57.00               26.00
# 34985                                56.00               28.00
# 34986                                56.00               29.00
# 34987                                64.00               34.00
#
#        labs_Calcium_last  labs_Phosphate measurement_last  \
# 0                 2.3500                           1.2100
# 1                 2.0000                           0.4000
# 2                 2.2691                           1.1253
# 3                 2.5800                           1.5000
# 4                 2.4900                           1.3700
# ...                  ...                              ...
# 34983             2.1800                           1.3300
# 34984             2.2067                           1.0356
# 34985             2.1500                           0.4900
# 34986             2.2000                           0.8000
# 34987             2.2800                           1.1300
#
#        labs_Magnesium measurement_last  death_7_day  death_14_day  \
# 0                               0.9800            0             0
# 1                               0.8000            0             0
# 2                               0.7749            0             0
# 3                               0.8200            0             0
# 4                               0.7300            0             0
# ...                                ...          ...           ...
# 34983                           1.1700            0             0
# 34984                           0.7696            0             0
# 34985                           0.7200            0             0
# 34986                           0.6900            0             0
# 34987                           0.7200            0             0
#
#        death_30_day  JOURNEY_ID
# 0                 0      567916
# 1                 0      572108
# 2                 0      565491
# 3                 0      584875
# 4                 0      584875
# ...             ...         ...
# 34983             0    17883870
# 34984             0    17907968
# 34985             0    17907968
# 34986             0    17907968
# 34987             0    17907968
#
# [34988 rows x 194 columns]

# %%
dmDf[['person_id', 'visit_occurrence_id']].drop_duplicates().shape
# Out:
# (7295, 2)

# %% [markdown]
# ## Merge data

# %%
mergedDf = demoDf.merge(
    dmDf,
    how='inner',
    left_on=['PATIENT_ID', 'EPISODE_ID'],
    right_on=['person_id', 'visit_occurrence_id'],
).drop(
    columns=['person_id', 'visit_occurrence_id']
)
mergedDf
# Out:
#        PATIENT_ID  EPISODE_ID  PARENT_EPISODE_ID STATUS STATUS_DESCRIPTION  \
# 0         2133327      567916             567916      D         Discharged
# 1         2197822      572108             572108      D         Discharged
# 2         2163117      592082             592082      D         Discharged
# 3         2163117      592082             592082      D         Discharged
# 4         2163117      592082             592082      D         Discharged
# ...           ...         ...                ...    ...                ...
# 34983     2449953    17683726           17683726      D         Discharged
# 34984     2514680    17684050           17684050      D         Discharged
# 34985      635285    17705709           17705709      D         Discharged
# 34986      635285    17705709           17705709      D         Discharged
# 34987      635285    17705709           17705709      D         Discharged
#
#                 START_DATETIME             END_DATETIME  \
# 0      2018-07-10 23:21:00.000  2018-09-05 13:15:00.000
# 1      2018-07-23 11:15:00.000  2018-07-25 14:37:00.000
# 2      2018-09-18 14:24:00.000  2018-10-22 14:35:00.000
# 3      2018-09-18 14:24:00.000  2018-10-22 14:35:00.000
# 4      2018-09-18 14:24:00.000  2018-10-22 14:35:00.000
# ...                        ...                      ...
# 34983  2023-05-08 08:05:00.000  2023-05-08 16:30:00.000
# 34984  2023-05-08 08:37:00.000  2023-05-08 15:40:00.000
# 34985  2023-05-12 15:02:53.000  2023-05-12 18:45:00.000
# 34986  2023-05-12 15:02:53.000  2023-05-12 18:45:00.000
# 34987  2023-05-12 15:02:53.000  2023-05-12 18:45:00.000
#
#           DATEOFDEATH_DATETIME   DATE_OF_BIRTH_DATETIME COUNTRY_OF_BIRTH  ...  \
# 0                          NaN  1944-08-20 00:00:00.000          Croatia  ...
# 1      2019-07-17 11:11:00.000  1928-10-05 00:00:00.000        Australia  ...
# 2                          NaN  1948-06-01 00:00:00.000        Australia  ...
# 3                          NaN  1948-06-01 00:00:00.000        Australia  ...
# 4                          NaN  1948-06-01 00:00:00.000        Australia  ...
# ...                        ...                      ...              ...  ...
# 34983                      NaN  1949-04-01 00:00:00.000        Australia  ...
# 34984                      NaN  1963-02-18 00:00:00.000        Australia  ...
# 34985                      NaN  1983-11-22 00:00:00.000        Australia  ...
# 34986                      NaN  1983-11-22 00:00:00.000        Australia  ...
# 34987                      NaN  1983-11-22 00:00:00.000        Australia  ...
#
#       labs_Total alkaline phosphatase level_last  \
# 0                                         223.33
# 1                                         536.00
# 2                                         146.00
# 3                                         135.00
# 4                                         137.00
# ...                                          ...
# 34983                                     124.59
# 34984                                     168.00
# 34985                                      75.00
# 34986                                     162.83
# 34987                                     153.22
#
#        labs_Total protein measurement_last labs_Globulin_last  \
# 0                                    65.56              39.00
# 1                                    55.00              36.00
# 2                                    70.00              51.00
# 3                                    68.00              50.00
# 4                                    65.00              47.00
# ...                                    ...                ...
# 34983                                68.81              34.00
# 34984                                59.00              40.00
# 34985                                77.00              38.00
# 34986                                65.92              38.79
# 34987                                62.86              36.99
#
#       labs_Calcium_last labs_Phosphate measurement_last  \
# 0                2.3500                          1.2100
# 1                2.0000                          0.4000
# 2                2.0300                          0.6400
# 3                2.0100                          0.7100
# 4                2.0100                          0.8100
# ...                 ...                             ...
# 34983            2.3540                          1.0755
# 34984            2.0491                          0.9229
# 34985            2.3994                          0.9425
# 34986            2.1986                          0.9349
# 34987            2.0900                          1.2600
#
#        labs_Magnesium measurement_last  death_7_day  death_14_day  \
# 0                               0.9800            0             0
# 1                               0.8000            0             0
# 2                               0.7700            0             0
# 3                               0.9200            0             0
# 4                               0.7800            0             0
# ...                                ...          ...           ...
# 34983                           0.7910            0             0
# 34984                           0.7257            0             0
# 34985                           0.7776            0             0
# 34986                           0.7200            0             0
# 34987                           0.7500            0             0
#
#        death_30_day  JOURNEY_ID
# 0                 0      567916
# 1                 0      572108
# 2                 0      592082
# 3                 0      592082
# 4                 0      592082
# ...             ...         ...
# 34983             0    17683726
# 34984             0    17684050
# 34985             0    17705709
# 34986             0    17705709
# 34987             0    17705709
#
# [34988 rows x 204 columns]

# %%
countryCountsDf = mergedDf[['PATIENT_ID', 'COUNTRY_OF_BIRTH']].drop_duplicates().groupby(by=['COUNTRY_OF_BIRTH']).agg(func='count').reset_index().rename(columns={'PATIENT_ID': 'Count'}).sort_values(by=['Count'], ascending=False)
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'England'), 'COUNTRY_OF_BIRTH'] = 'United Kingdom'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'United Kingdom, Channel Islands & Isle of Man'), 'COUNTRY_OF_BIRTH'] = 'United Kingdom'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'Scotland'), 'COUNTRY_OF_BIRTH'] = 'United Kingdom'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'Wales'), 'COUNTRY_OF_BIRTH'] = 'United Kingdom'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'United States of America'), 'COUNTRY_OF_BIRTH'] = 'United States'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'Australian External Territories'), 'COUNTRY_OF_BIRTH'] = 'Australia'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'Australian Antarctic Territory'), 'COUNTRY_OF_BIRTH'] = 'Australia'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'China (Excludes SARS & Taiwan)'), 'COUNTRY_OF_BIRTH'] = 'China'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'Hong Kong(Special Administrative Region of China)'), 'COUNTRY_OF_BIRTH'] = 'China'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'Chinese Asia (includes Mongolia)'), 'COUNTRY_OF_BIRTH'] = 'China'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'Macau (Special Administration Region of China)'), 'COUNTRY_OF_BIRTH'] = 'China'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'Japan and the Koreas, nfd'), 'COUNTRY_OF_BIRTH'] = 'Japan'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'Russian Federation'), 'COUNTRY_OF_BIRTH'] = 'Russia'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'East Timor'), 'COUNTRY_OF_BIRTH'] = 'Timor-Leste'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'Burma (Myanmar)'), 'COUNTRY_OF_BIRTH'] = 'Myanmar'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'Aland Islands'), 'COUNTRY_OF_BIRTH'] = 'Finland'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'Former Yugoslav Republic of Macedonia'), 'COUNTRY_OF_BIRTH'] = 'Macedonia'
countryCountsDf.loc[(countryCountsDf.COUNTRY_OF_BIRTH == 'Bosnia-Herzegovina'), 'COUNTRY_OF_BIRTH'] = 'Bosnia And Herzegovina'


countryCountsDf
# Out:
#    COUNTRY_OF_BIRTH  Count
# 4         Australia   1608
# 39           Greece    130
# 31   United Kingdom     71
# 63      New Zealand     45
# 42            India     41
# ..              ...    ...
# 87           Taiwan      1
# 95       Uzbekistan      1
# 94          Uruguay      1
# 98            Yemen      1
# 99           Zambia      1
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Read country to region mapping data

# %%
import os

from pathlib import Path

import pandas as pd


mapDf = pd.read_csv(Path(os.environ['EHR_DATA_BASE'], 'blood_pos_cohort_20240614', 'etc', 'continents2.csv'))
mapDf
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
#              sub-region intermediate-region  region-code  sub-region-code  \
# 0         Southern Asia                 NaN        142.0             34.0
# 1       Northern Europe                 NaN        150.0            154.0
# 2       Southern Europe                 NaN        150.0             39.0
# 3       Northern Africa                 NaN          2.0             15.0
# 4             Polynesia                 NaN          9.0             61.0
# ..                  ...                 ...          ...              ...
# 244           Polynesia                 NaN          9.0             61.0
# 245     Northern Africa                 NaN          2.0             15.0
# 246        Western Asia                 NaN        142.0            145.0
# 247  Sub-Saharan Africa      Eastern Africa          2.0            202.0
# 248  Sub-Saharan Africa      Eastern Africa          2.0            202.0
#
#      intermediate-region-code
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 244                       NaN
# 245                       NaN
# 246                       NaN
# 247                      14.0
# 248                      14.0
#
# [249 rows x 11 columns]

# %%
mappedDf = countryCountsDf.merge(
    mapDf,
    how='left',
    left_on=['COUNTRY_OF_BIRTH'],
    right_on=['name']
)
mappedDf
# Out:
#    COUNTRY_OF_BIRTH  Count            name alpha-2 alpha-3  country-code  \
# 0         Australia   1608       Australia      AU     AUS          36.0
# 1            Greece    130          Greece      GR     GRC         300.0
# 2    United Kingdom     71  United Kingdom      GB     GBR         826.0
# 3       New Zealand     45     New Zealand      NZ     NZL         554.0
# 4             India     41           India      IN     IND         356.0
# ..              ...    ...             ...     ...     ...           ...
# 95           Taiwan      1          Taiwan      TW     TWN         158.0
# 96       Uzbekistan      1      Uzbekistan      UZ     UZB         860.0
# 97          Uruguay      1         Uruguay      UY     URY         858.0
# 98            Yemen      1           Yemen      YE     YEM         887.0
# 99           Zambia      1          Zambia      ZM     ZMB         894.0
#
#        iso_3166-2    region                       sub-region  \
# 0   ISO 3166-2:AU   Oceania        Australia and New Zealand
# 1   ISO 3166-2:GR    Europe                  Southern Europe
# 2   ISO 3166-2:GB    Europe                  Northern Europe
# 3   ISO 3166-2:NZ   Oceania        Australia and New Zealand
# 4   ISO 3166-2:IN      Asia                    Southern Asia
# ..            ...       ...                              ...
# 95  ISO 3166-2:TW      Asia                     Eastern Asia
# 96  ISO 3166-2:UZ      Asia                     Central Asia
# 97  ISO 3166-2:UY  Americas  Latin America and the Caribbean
# 98  ISO 3166-2:YE      Asia                     Western Asia
# 99  ISO 3166-2:ZM    Africa               Sub-Saharan Africa
#
#    intermediate-region  region-code  sub-region-code  intermediate-region-code
# 0                  NaN          9.0             53.0                       NaN
# 1                  NaN        150.0             39.0                       NaN
# 2                  NaN        150.0            154.0                       NaN
# 3                  NaN          9.0             53.0                       NaN
# 4                  NaN        142.0             34.0                       NaN
# ..                 ...          ...              ...                       ...
# 95                 NaN        142.0             30.0                       NaN
# 96                 NaN        142.0            143.0                       NaN
# 97       South America         19.0            419.0                       5.0
# 98                 NaN        142.0            145.0                       NaN
# 99      Eastern Africa          2.0            202.0                      14.0
#
# [100 rows x 13 columns]

# %% [markdown]
# ## Plot

# %% [markdown]
# ### Plot regions

# %%
regionDf = mappedDf.groupby(by=['region']).agg(func={'Count': 'sum'}).reset_index().sort_values(by=['Count'])
regionDf
# Out:
#      region  Count
# 1  Americas     33
# 0    Africa     47
# 2      Asia    221
# 3    Europe    540
# 4   Oceania   1669

# %%
import matplotlib.pyplot as plt 
import seaborn 

fig, ax = plt.subplots(figsize=(8, 8))

# define Seaborn color palette to use 
palette_color = seaborn.color_palette("pastel")

# plotting data on chart 
plt.pie(regionDf.Count, labels=regionDf.region, colors=palette_color, autopct='%.0f%%') 

ax.set_title('Region wise patient country of birth')

# displaying chart 
plt.show()

# %% [markdown]
# ### Plot sub-regions

# %%
subregionDf = mappedDf.groupby(by=['sub-region']).agg(func={'Count': 'sum'}).reset_index().sort_values(by=['Count'])
subregionDf.loc[(subregionDf['sub-region'] == 'Melanesia'), 'sub-region'] = 'Pacific Islands'
subregionDf.loc[(subregionDf['sub-region'] == 'Polynesia'), 'sub-region'] = 'Pacific Islands'
subregionDf.loc[(subregionDf['sub-region'] == 'Central Asia'), 'sub-region'] = 'Eastern Asia'
subregionDf.loc[(subregionDf['sub-region'] == 'Central Asia'), 'sub-region'] = 'Eastern Asia'
subregionDf.loc[(subregionDf['sub-region'] == 'Northern Africa'), 'sub-region'] = 'Northern & Sub-Saharan Africa'
subregionDf.loc[(subregionDf['sub-region'] == 'Sub-Saharan Africa'), 'sub-region'] = 'Northern & Sub-Saharan Africa'
subregionDf = subregionDf.groupby(by=['sub-region']).agg(func={'Count': 'sum'}).reset_index().sort_values(by=['Count'])
subregionDf
# Out:
#                          sub-region  Count
# 7                   Pacific Islands     11
# 5                  Northern America     15
# 3   Latin America and the Caribbean     18
# 11                     Western Asia     43
# 1                      Eastern Asia     46
# 4     Northern & Sub-Saharan Africa     47
# 12                   Western Europe     47
# 8                South-eastern Asia     59
# 9                     Southern Asia     73
# 2                    Eastern Europe    120
# 6                   Northern Europe    155
# 10                  Southern Europe    218
# 0         Australia and New Zealand   1658

# %%
import matplotlib.pyplot as plt 
import seaborn 


fig, ax = plt.subplots(figsize=(8, 8))

# define Seaborn color palette to use 
palette_color = seaborn.color_palette("pastel")

# plotting data on chart 
plt.pie(subregionDf.Count, labels=subregionDf['sub-region'], colors=palette_color, autopct='%.0f%%') 

ax.set_title('Sub-region wise patient country of birth')
# displaying chart 
plt.show()
